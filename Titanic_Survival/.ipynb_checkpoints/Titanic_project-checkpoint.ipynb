# %% [markdown]
# # Titanic Survival:  Data Analysis

# %% [markdown]
# ![](http://i586.photobucket.com/albums/ss306/realphotos/TITANIC/5.jpg)

# %% [markdown]
# "Cross-sectional drawing showing ice penetrating the double bottom of the Titanic." [source](http://bit.ly/29YeBu8)

# %% [markdown]
# ### Background

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The RMS Titanic was a British passenger liner which sank in the North Atlantic off the coast of Newfoundland on April 15, 1912, after colliding with an iceberg.  While a number of passengers survived on lifeboats and escaped to safety aboard the RMS Carpathia, many others perished as the ship sank into the sea.

# %% [markdown]
# ### Goals

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;In order to understand characteristics which may lead people to higher chance of survival, we will analyze the Titanic passenger data set in order to build and test a logistic regression model predicting survival.

# %% [markdown]
# ### Risks & Assumptions

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;A browse of [Encyclopedia Titanica](https://www.encyclopedia-titanica.org/) shows that a surprising amount of passenger biographical information remains disputed; we will assume that all non-null values in this data set are correct.  When imputing missing values which cannot be found on that site, we take the risk of assuming that the median value for all other passengers is a reasonable estimate.  This slightly narrows our standard deviation for the given feature.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
from matplotlib import cm as colorm
from matplotlib import patheffects as path_effects

from scipy.stats import gaussian_kde

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn import linear_model
from sklearn.feature_selection import RFECV, SelectKBest, f_classif
from sklearn.metrics import confusion_matrix, roc_curve, auc, accuracy_score, \
    precision_score, recall_score, classification_report
from sklearn.model_selection import GridSearchCV, train_test_split, KFold, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, \
    ExtraTreesClassifier, RandomForestClassifier

from sqlalchemy import create_engine

# %matplotlib inline

# %%
## engine = create_engine('postgresql://\
##  dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/titanic')
## df = pd.read_sql('SELECT * FROM train', engine)
## df.to_csv('assets/titanic.csv', encoding='utf-8')

# %% [markdown]
# Run this cell to load the dataframe obtained directly above:

# %%
titanic = pd.read_csv('assets/titanic.csv')

titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ### PassengerId

# %% [markdown]
# This column appears to be the index offset by 1; it is not immediately apparent in which order the observations are listed, so we will keep this as a feature for now:

# %%
if list(titanic['PassengerId']) == range(1, len(titanic) + 1, 1):
    print 'PassengerId is index offset by 1.'
else:
    print titanic['PassengerId'].describe()
# Out:
# PassengerId is index offset by 1.

# %% [markdown]
# ### Sex

# %%
titanic['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# We'll dummify males to 1 and females to 0:

# %%
titanic.loc[:, 'Sex'] = titanic.loc[:, 'Sex'].map({'male' : 1, 'female' : 0})

# %% [markdown]
# ### Survived

# %%
titanic['Survived'].value_counts() # will be target variable
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic['Survived'] = LabelEncoder().fit_transform(titanic['Survived'])
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ### Pclass

# %%
titanic['Pclass'].value_counts() # ranked categorical; getting dummies loses ranked aspect
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### Age

# %% [markdown]
# About 20% of ages are missing.  Many of them are available on [Encyclopedia Titanica](https://www.encyclopedia-titanica.org/), so we'll look them up and put them in a dictionary:

# %%
## to get list of names whose ages are missing:
## list(titanic.loc[pd.isnull(titanic['Age']), 'Name'])

name_age = {
     'Moran, Mr. James' : 1884,
     'Williams, Mr. Charles Eugene' : 1888,
     'Masselmani, Mrs. Fatima' : 1890,
     'Emir, Mr. Farred Chehab' : 1886,
     'O\'Dwyer, Miss. Ellen "Nellie"' : 1888,
     'Todoroff, Mr. Lalio' : 1889,
     'Spencer, Mrs. William Augustus (Marie Eugenie)' : 1855,
     'Glynn, Miss. Mary Agatha' : 1893,
     'Mamee, Mr. Hanna' : 1893,
     'Kraeff, Mr. Theodor' : np.nan,
     'Rogers, Mr. William John' : 1882,
     'Lennon, Mr. Denis' : 1891,
     'O\'Driscoll, Miss. Bridget' : 1885,
     'Samaan, Mr. Youssef' : 1895,
     'Woolner, Mr. Hugh' : 1866,
     'Stewart, Mr. Albert A' : 1848,
     'Moubarek, Master. Gerios' : 1904,
     'Staneff, Mr. Ivan' : 1889,
     'Moutal, Mr. Rahamin Haim' : 1884,
     'McDermott, Miss. Brigdet Delia' : 1881,
     'Slocovski, Mr. Selman Francis' : 1892,
     'Shorney, Mr. Charles Joseph' : 1889,
     'Petroff, Mr. Pastcho ("Pentcho")' : 1883,
     'Moss, Mr. Albert Johan' : 1882,
     'Moran, Miss. Bertha' : 1883, 
     'Moore, Mr. Leonard Charles' : 1893,
     'McMahon, Mr. Martin' : 1893,
     'Peter, Miss. Anna' : 1909,
     'Boulos, Mrs. Joseph (Sultana)' : 1872,
     'Olsen, Mr. Ole Martin' : 1885,
     'Smiljanic, Mr. Mile' : 1874,
     'Sage, Master. Thomas Henry' : 1907,
     'Chibnall, Mrs. (Edith Martha Bowerman)' : 1864,
     'Baumann, Mr. John D' : 1864,
     'Lefebre, Master. Henry Forbes' : 1906,
     'Sage, Miss. Constance Gladys' : 1904,
     'Pernot, Mr. Rene' : 1872,
     'Rood, Mr. Hugh Roscoe' : 1873,
     'O\'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)' : 1884,
     'Mernagh, Mr. Robert' : 1883,
     'Madigan, Miss. Margaret "Maggie"' : 1890,
     'Sage, Mr. Frederick' : 1895,
     'Kiernan, Mr. Philip' : 1890,
     'Nenkoff, Mr. Christo' : 1890, 
     'Lefebre, Miss. Mathilde' : 1899,
     'Harknett, Miss. Alice Phoebe' : 1890,
     'Zabour, Miss. Thamine' : 1893,
     'Murphy, Miss. Katherine "Kate"' : 1893,
     'Reed, Mr. James George' : 1893,
     'Thorne, Mrs. Gertrude Maybelle' : 1875,
     'Smith, Mr. Thomas' : 1885, ## Smyth
     'Henry, Miss. Delia' : 1890,
     'Cairns, Mr. Alexander' : 1883,
     'Healy, Miss. Hanora "Nora"' : 1879, ## Honor
     'Parkes, Mr. Francis "Frank"' : 1890,
     'Smith, Mr. Richard William' : 1854,
     'Lewy, Mr. Ervin G' : 1881,
     'Saalfeld, Mr. Adolphe' : 1865,
     'Kelly, Miss. Anna Katherine "Annie Kate"' : 1891,
     'McCoy, Mr. Bernard' : 1887,
     'Keane, Miss. Nora A' : 1866,
     'Williams, Mr. Howard Hugh "Harry"' : 1884,
     'Fleming, Miss. Margaret' : 1870,
     'Sage, Mr. George John Jr' : 1892,
     'McCoy, Miss. Agnes' : 1882,
     'Frauenthal, Mrs. Henry William (Clara Heinsheimer)' : 1869,
     'Denkoff, Mr. Mitto' : 1882,
     'Davison, Mrs. Thomas Henry (Mary E Finck)' : 1878,
     'Williams-Lambert, Mr. Fletcher Fellows' : 1868,
     'Yousif, Mr. Wazli' : 1889,
     'McGovern, Miss. Mary' : 1890,
     'Mockler, Miss. Helen Mary "Ellie"' : 1889,
     "O'Brien, Mr. Thomas" : 1885,
     'Moussa, Mrs. (Mantoura Boulos)' : 1877,
     'Jermyn, Miss. Annie' : 1885,
     'Meyer, Mrs. Edgar Joseph (Leila Saks)' : 1886,
     'Plotcharsky, Mr. Vasil' : 1885,
     'Sadlier, Mr. Matthew' : 1893,
     'Lefebre, Miss. Ida' : 1908,
     'Sdycoff, Mr. Todor' : 1870,
     'Hart, Mr. Henry' : 1883,
     'Cunningham, Mr. Alfred Fleming' : 1890,
     'Meek, Mrs. Thomas (Annie Louise Rowley)' : 1880,
     'Gheorgheff, Mr. Stanio' : np.nan,
     'Wiseman, Mr. Phillippe' : 1858,
     'Flynn, Mr. James' : 1841,
     'Thorneycroft, Mrs. Percival (Florence Kate White)' : 1875,
     'Johannesen-Bratthammer, Mr. Bernt' : 1882,
     'Hagland, Mr. Ingvald Olai Olsen' : 1884,
     'Peduzzi, Mr. Joseph' : 1887,
     'Kenyon, Mrs. Frederick R (Marion)' : 1871,
     'O\'Connor, Mr. Maurice' : 1895,
     'Maisner, Mr. Simon' : 1878,
     'Campbell, Mr. William' : 1890,
     'Scanlan, Mr. James' : 1890,
     'Keefe, Mr. Arthur' : 1867,
     'Clifford, Mr. George Quincy' : 1871,
     'Frost, Mr. Anthony Wood "Archie"' : 1873,
     'Lefebre, Miss. Jeannie' : 1903,
     'Hagland, Mr. Konrad Mathias Reiersen' : 1892,
     'Yousseff, Mr. Gerious' : 1886,
     'Shellard, Mr. Frederick William' : 1857,
     'O\'Sullivan, Miss. Bridget Mary' : 1890,
     'Bradley, Mr. George ("George Arthur Brayton")' : 1874, ## Brereton
     'Webber, Mr. James' : 1846,
     'Ryan, Mr. Patrick' : 1882,
     'Lahoud, Mr. Sarkis' : 1877,
     'Kassem, Mr. Fared' : 1893,
     'Farthing, Mr. John' : 1863,
     'Toufik, Mr. Nakli' : 1895,
     'Peter, Mrs. Catherine (Catherine Rizk)' : 1888,
     'Risien, Mr. Samuel Beard' : 1842,
     'Padro y Manent, Mr. Julian' : 1885, ## Padron y Manent
     'O\'Brien, Mr. Timothy' : 1891, ## Denis
     'Robbins, Mr. Victor' : 1867,
     'Morrow, Mr. Thomas Rowan' : 1881,
     'Simmons, Mr. John' : 1872,
     'Meanwell, Miss. (Marion Ogden)' : 1849,
     'Doharr, Mr. Tannous' : 1884, ## Daher
     'Kelly, Miss. Mary' : 1890, 
     'Caram, Mrs. Joseph (Maria Elias)' : 1894,
     'Paulner, Mr. Uscher' : np.nan,
     'Murdlin, Mr. Joseph' : 1890,
     'Bourke, Miss. Mary' : 1871,
     'Leitch, Miss. Jessie Wills' : 1880,
     'Boulos, Mr. Hanna' : 1894,
     'Slabenoff, Mr. Petco' : 1870, 
     'Harrington, Mr. Charles H' : 1875,
     'Jardin, Mr. Jose Neto' : 1890, ## Jardim
     'Murphy, Miss. Margaret Jane' : 1886,
     'Horgan, Mr. John' : 1890,
     'O\'Connell, Mr. Patrick D' : 1894, ## middle name Denis
     'Parr, Mr. William Henry Marsh' : 1882,
     'Thorneycroft, Mr. Percival' : 1875,
     'Foo, Mr. Choong' : 1880,
     'Willey, Mr. Edward' : 1891,
     'Mitkoff, Mr. Mito' : 1889,
     'O\'Leary, Miss. Hanora "Norah"' : 1895,
     'Radeff, Mr. Alexander' : 1885,
     'Rommetvedt, Mr. Knud Paust' : 1863,
     'Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)' : 1862,
     'Watson, Mr. Ennis Hastings' : 1893,
     'Peters, Miss. Katie' : 1884,
     'Lam, Mr. Ali' : 1874,
     'Mullens, Miss. Katherine "Katie"' : 1890, ## Catherine Mullen
     'Moubarek, Master. Halim Gonios ("William George")' : 1907,
     'Klaber, Mr. Herman' : 1870, 
     'McEvoy, Mr. Michael' : 1892,
     'Mannion, Miss. Margareth' : 1883,
     'Knight, Mr. Robert J' : 1871,
     'Ivanoff, Mr. Kanio' : 1892,
     'Nankoff, Mr. Minko' : 1880,
     'Hawksford, Mr. Walter James' : 1867,
     'Garfirth, Mr. John' : 1889,
     'Brewe, Dr. Arthur Jackson' : 1866,
     'Moran, Mr. Daniel J' : 1884,
     'Elias, Mr. Dibo' : 1883,
     'Tobin, Mr. Roger' : 1891,
     'Kilgannon, Mr. Thomas J' : 1890,
     'Johnston, Mr. Andrew G' : 1876,
     'Keane, Mr. Andrew "Andy"' : 1889, ## Kean
     'Sage, Miss. Stella Anna' : 1891,
     'Hoyt, Mr. William Fisher' : 1869,
     'Fry, Mr. Richard' : 1873,
     'Flynn, Mr. John' : 1864,
     'Lam, Mr. Len' : 1889,
     'McCormack, Mr. Thomas Joseph' : 1892,
     'Saad, Mr. Amin' : 1882,
     'Sirota, Mr. Maurice' : 1892, ## Morris
     'Marechal, Mr. Pierre' : 1883,
     'Sage, Mr. Douglas Bullen' : 1894,
     'Goldenberg, Mrs. Samuel L (Edwiga Grabowska)' : np.nan, ## much confusion on this
     'Razi, Mr. Raihed' : 1882,
     'Sage, Miss. Dorothy Edith "Dolly"' : 1897,
     'van Melkebeke, Mr. Philemon' : 1889,
     'Laleff, Mr. Kristo' : 1889,
     'Johnston, Miss. Catherine Helen "Carrie"' : 1905 ## middle name Nellie
}

# %%
for i in range(len(titanic)):
    try:
        titanic.loc[i, 'Age'] = 1912 - name_age[titanic.loc[i, 'Name']]
    except:
        pass

# %%
titanic[titanic['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 42            43         0       3
# 420          421         0       3
# 584          585         0       3
# 849          850         1       1
#
#                                              Name  Sex  Age  SibSp  Parch  \
# 42                            Kraeff, Mr. Theodor    1  NaN      0      0
# 420                        Gheorgheff, Mr. Stanio    1  NaN      0      0
# 584                           Paulner, Mr. Uscher    1  NaN      0      0
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)    0  NaN      1      0
#
#      Ticket     Fare Cabin Embarked
# 42   349253   7.8958   NaN        C
# 420  349254   7.8958   NaN        C
# 584    3411   8.7125   NaN        C
# 849   17453  89.1042   C92        C

# %% [markdown]
# We'll try to impute missing ages soon using sex, title, and passenger class info.

# %% [markdown]
# ### Title

# %%
titanic['title'] = [x.split(', ')[1].split(' ')[0].strip('.') for x in titanic['Name']]

titanic['title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Col           2
# Mlle          2
# Jonkheer      1
# Ms            1
# Lady          1
# the           1
# Don           1
# Mme           1
# Capt          1
# Sir           1
# Name: title, dtype: int64

# %%
title_dict = {
    "Capt"      :  "Professional",
    "Col"       :  "Professional",
    "Major"     :  "Professional",
    "Jonkheer"  :  "Royalty",
    "Don"       :  "Royalty",
    "Sir"       :  "Royalty",
    "Dr"        :  "Professional",
    "Rev"       :  "Professional",
    "the"       :  "Royalty", ## Countess
    "Mme"       :  "Mrs",
    "Mlle"      :  "Miss",
    "Ms"        :  "Mrs",
    "Mr"        :  "Mr",
    "Mrs"       :  "Mrs",
    "Miss"      :  "Miss",
    "Master"    :  "Master",
    "Lady"      :  "Royalty"
}

titanic['title'] = titanic['title'].apply(lambda x: title_dict[x])

# %%
titanic['title'].value_counts()
# Out:
# Mr              517
# Miss            184
# Mrs             127
# Master           40
# Professional     18
# Royalty           5
# Name: title, dtype: int64

# %%
titanic.groupby(['Pclass', 'Sex', 'title'])['Age'].median()
# Out:
# Pclass  Sex  title
# 1       0    Miss            30.0
#              Mrs             42.0
#              Professional    49.0
#              Royalty         40.5
#         1    Master           4.0
#              Mr              41.0
#              Professional    50.0
#              Royalty         40.0
# 2       0    Miss            24.0
#              Mrs             31.5
#         1    Master           1.0
#              Mr              30.0
#              Professional    46.5
# 3       0    Miss            19.0
#              Mrs             31.5
#         1    Master           5.0
#              Mr              26.0
# Name: Age, dtype: float64

# %%
## impute the four missing ages
titanic['Age'].fillna(titanic.groupby(['Pclass', 'Sex', 'title'])['Age'].\
                      transform('median'), inplace=True)

# %%
titanic['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### SibSp

# %% [markdown]
# Number of siblings/spouses aboard

# %%
titanic['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %% [markdown]
# ### Parch

# %% [markdown]
# Number of parents/children aboard

# %%
titanic['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# ### Ticket

# %%
titanic['Ticket'].value_counts()[0:10]
# Out:
# CA. 2343        7
# 347082          7
# 1601            7
# 347088          6
# CA 2144         6
# 3101295         6
# 382652          5
# S.O.C. 14879    5
# PC 17757        4
# 4133            4
# Name: Ticket, dtype: int64

# %% [markdown]
# This information is difficult to parse; we will not end up using this feature for our model.

# %%
titanic.drop('Ticket', axis = 1, inplace = True)

# %% [markdown]
# ### Cabin

# %%
titanic['Cabin'].head(10)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %% [markdown]
# Over 3/4 of this column is missing; we will not use this feature in our analysis.  It seems as though more cabin information is available on Encyclopedia Titanica than is provided in this data set; perhaps in the future we will investigate filling in missing values with that information.

# %%
titanic.drop('Cabin', axis = 1, inplace = True)

# %% [markdown]
# ### Fare

# %%
titanic['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
titanic[titanic['Fare'] == 0]
# Out:
#      PassengerId  Survived  Pclass                              Name  Sex  \
# 179          180         0       3               Leonard, Mr. Lionel    1
# 263          264         0       1             Harrison, Mr. William    1
# 271          272         1       3      Tornquist, Mr. William Henry    1
# 277          278         0       2       Parkes, Mr. Francis "Frank"    1
# 302          303         0       3   Johnson, Mr. William Cahoone Jr    1
# 413          414         0       2    Cunningham, Mr. Alfred Fleming    1
# 466          467         0       2             Campbell, Mr. William    1
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"    1
# 597          598         0       3               Johnson, Mr. Alfred    1
# 633          634         0       1     Parr, Mr. William Henry Marsh    1
# 674          675         0       2        Watson, Mr. Ennis Hastings    1
# 732          733         0       2              Knight, Mr. Robert J    1
# ...

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Spot-checking a few of these, the fares don't seem to be available on Encyclopedia Titanica.  It does seem unlikely that they are true zeroes; we will impute based on median for corresponding passenger class, sex, and title.

# %%
titanic.groupby(['Pclass', 'Sex', 'title'])['Fare'].median()
# Out:
# Pclass  Sex  title
# 1       0    Miss             88.25000
#              Mrs              79.20000
#              Professional     25.92920
#              Royalty          63.05000
#         1    Master          120.00000
#              Mr               42.40000
#              Professional     35.50000
#              Royalty          27.72080
# 2       0    Miss             13.00000
#              Mrs              26.00000
#         1    Master           26.00000
#              Mr               13.00000
#              Professional     13.00000
# 3       0    Miss              8.75625
#              Mrs              15.97500
#         1    Master           28.51250
#              Mr                7.89580
# Name: Fare, dtype: float64

# %%
titanic.loc[list(titanic[titanic['Fare'] == 0].index), 'Fare'] = np.nan

titanic['Fare'].fillna(titanic.groupby(['Pclass', 'Sex', 'title'])['Fare'].\
                      transform('mean'), inplace=True)

# %%
titanic['Fare'].isnull().sum()
# Out:
# 0

# %%
titanic['Fare'].describe()
# Out:
# count    891.000000
# mean      32.759173
# std       49.611083
# min        4.012500
# 25%        7.925000
# 50%       14.500000
# 75%       31.275000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# The fares are listed in GBP; not sure why they have so many decimal places, but we'll round them to two:

# %%
titanic['Fare'] = titanic['Fare'].apply(lambda x: round(x, 2))

# %% [markdown]
# ### Embarked

# %% [markdown]
# S - Southampton, UK
#
# C - Cherbourg, France
#
# Q - Queenstown, Cork, Ireland

# %%
titanic[titanic['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#      Sex   Age  SibSp  Parch  Fare Embarked title
# 61     0  38.0      0      0  80.0      NaN  Miss
# 829    0  62.0      0      0  80.0      NaN   Mrs

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Consulting records on Encyclopedia Titanica, we find that these passengers boarded together at Southampton.

# %%
titanic['Embarked'].fillna('S', inplace = True)

# %%
titanic['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ### PassengerId

# %%
sns.pairplot(titanic[['Age', 'Fare', 'PassengerId', 'Pclass']], hue = 'Pclass')
plt.show()

# %% [markdown]
# PassengerId appears randomly assigned; we will not use it in the model.

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Histogram of Age

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

age_hist = plt.hist(titanic['Age'], color = 'lightsteelblue', alpha = 0.8, bins = 20)
plt.axvline(titanic['Age'].median(), color='b', linestyle='dashed', linewidth=1.5, \
            label = 'median', alpha = 0.8)
plt.axvline(titanic['Age'].mean(), color='g', linestyle='dashed', linewidth=1.5, \
            label = 'mean', alpha = 0.8)

plt.title('Titanic: Passenger Age', fontsize = 24, y = 1.03)

plt.ylabel('Count', fontsize = 18)
plt.ylim([0, 151])
plt.yticks(range(0, 200, 50), fontsize = 14)

plt.xlabel('Age (years)', fontsize = 18)
plt.xlim([0, max(titanic['Age'])])
plt.xticks(range(0, 90, 10), fontsize = 14)

plt.grid(which='major', axis = 'x')

density = gaussian_kde(titanic['Age'])
xs = np.linspace(titanic['Age'].min(), titanic['Age'].max(), 1000)
density.covariance_factor = lambda : 0.25
density._compute_covariance()
plt.plot(xs,density(xs)*100000/30, linewidth = 3.0, label = 'Gaussian KDE')

plt.legend(loc='center right', fontsize = 14)

plt.show()

# %%
titanic.sort_values(by = 'Age', ascending = False).head(1)
# Out:
#      PassengerId  Survived  Pclass                                  Name  Sex  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson    1
#
#       Age  SibSp  Parch  Fare Embarked title
# 630  80.0      0      0  30.0        S    Mr

# %% [markdown]
# Looks like there are mostly people in their 20's and 30s, some traveling with children.  The oldest person on board is an 80 year-old man.

# %% [markdown]
# ### Histogram of Fare

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

age_hist = plt.hist(titanic['Fare'], color = 'lightsteelblue', alpha = 0.8, bins = 20)
plt.axvline(titanic['Fare'].median(), color='b', linestyle='dashed', linewidth=1.5, \
            label = 'median', alpha = 0.8)
plt.axvline(titanic['Fare'].mean(), color='g', linestyle='dashed', linewidth=1.5, \
            label = 'mean', alpha = 0.8)

plt.title('Titanic: Passenger Fare', fontsize = 24, y = 1.03)

plt.ylabel('Count', fontsize = 18)
plt.ylim([-10, 710])
plt.yticks(range(0, 800, 100), fontsize = 14)

plt.xlabel('Fare (GBP)', fontsize = 18)
plt.xlim([0, max(titanic['Fare'])])
plt.xticks(range(0, 600, 100), fontsize = 14)

plt.grid(which='major', axis = 'x')

plt.axhline(0, linewidth = 0.75, color = 'k', alpha = 0.4)

density = gaussian_kde(titanic['Fare'])
xs = np.linspace(titanic['Fare'].min(), titanic['Fare'].max(), 1000)
density.covariance_factor = lambda : 0.4
density._compute_covariance()
plt.plot(xs,density(xs)*100000/3, linewidth = 2.0, label = 'Gaussian KDE')

plt.legend(loc='center', fontsize = 14)

plt.show()

# %%
fig, ax1 = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(8)

plt.boxplot(titanic['Fare'], 0, 'gD')

ax1.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
               alpha=0.5)

ax1.set_axisbelow(True)
ax1.set_title('Titanic: Passenger Fare', y =1.03, fontsize = 24)
ax1.set_ylabel('Fare Paid (GBP)', fontsize = 18)

numBoxes = 1
ax1.set_xlim(0.5, numBoxes + 0.5)
ax1.set_ylim(-10, 610)
xtickNames = plt.setp(ax1, xticklabels=[''])
plt.setp(xtickNames, fontsize=14)

plt.show()

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Who paid so much money?

# %%
titanic.sort_values(by = 'Fare', ascending = False).head(3)
# Out:
#      PassengerId  Survived  Pclass                                Name  Sex  \
# 737          738         1       1              Lesurer, Mr. Gustave J    1
# 258          259         1       1                    Ward, Miss. Anna    0
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez    1
#
#       Age  SibSp  Parch    Fare Embarked title
# 737  35.0      0      0  512.33        C    Mr
# 258  35.0      0      0  512.33        C  Miss
# 679  36.0      0      1  512.33        C    Mr

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Median fare is 14.50 GBP.  The three passengers listed above were in the nicest suites on the ship, according to Encyclopedia Titanica.  Perhaps not surprisingly, they survived.

# %% [markdown]
# ### Scatterplot of Fare vs. Age, by Sex and Survival

# %% [markdown]
# (NB this plot cuts off the three highest-paying passengers discussed above.)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

fig.set_figwidth(12)
fig.set_figheight(8)

gender_dict = {
    1 : 'male',
    0 : 'female'
}

survival_dict = {
    0 : ['o', 'dead'],
    1 : ['o', 'alive']
}

color_dict = {
    0 : ['black', 'black'],
    1 : ['hotpink', 'dodgerblue']
}

plot_dict = {
    'axis' : [ax1, ax2],
    'title' : ['Titanic: Fare vs Age (Male)', 'Titanic: Fare vs Age (Female)'],
}

for i in [0, 1]:

    axis = plot_dict['axis'][i]    
    axis.set_title(plot_dict['title'][i], fontsize = 20, y = 1.0)
    axis.set_ylim([-10, 320])
    axis.set_yticks(range(0, 350, 50))
    ax1.set_ylabel('Fare (USD)', fontsize = 16)
    axis.set_xlim([-2, 85])
    axis.set_xticks(range(0, 90, 10))
    axis.set_xlabel('Age (years)', fontsize = 16)
    axis.axhline(0, color = 'black', linewidth = 1, alpha = 0.3)
    axis.axvline(0, color = 'black', linewidth = 1, alpha = 0.3)

for gender in [(1, ax1), (0, ax2)]:
    for survival in [0, 1]:
        gender[1].scatter(
            titanic.loc[(titanic['Sex'] == gender[0]) & (titanic['Survived'] == survival),'Age'],
            titanic.loc[(titanic['Sex'] == gender[0]) & (titanic['Survived'] == survival),'Fare'],
            color = color_dict[survival][gender[0]], alpha = 0.5, s = 40,
            marker = survival_dict[survival][0],
            label = '{}, {}'.format(gender_dict[gender[0]], survival_dict[survival][1]))
        gender[1].legend(loc = 'best', fontsize = 13)
        
plt.tight_layout()

plt.show()

# %%
titanic[(titanic['Age'] < 10) & (titanic['Fare'] > 150)]
# Out:
#      PassengerId  Survived  Pclass                            Name  Sex   Age  \
# 297          298         0       1    Allison, Miss. Helen Loraine    0  2.00
# 305          306         1       1  Allison, Master. Hudson Trevor    1  0.92
#
#      SibSp  Parch    Fare Embarked   title
# 297      1      2  151.55        S    Miss
# 305      1      2  151.55        S  Master

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Those two children with fares just over 150 GBP look like they're probably siblings; indeed, we confirm they are.  The boy survived and the girl died.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Otherwise, from this scatterplot we can see, for example, that male children and well-paying females had a relatively survival rate.  It looks like other males had poor survival rates.  There were not as many older women as older men, either alive or dead.  The 80 year old man perhaps got helped off because he was so old.  It is clear from inspection that the proportion of surviving females is higher than that of surviving males.

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Get dummies

# %%
def dummies(my_df, cols):
    '''For a dataframe and list of (<column name>, <dummy prefix>) tuples, 
    this function will dummify the columns listed and name the dummies using the prefix'''
    for column in cols:
        my_df = pd.concat([my_df.drop(column[0], axis = 1), pd.get_dummies(my_df[column[0]], \
                    drop_first = False, prefix = column[1])], axis = 1)
    return my_df

# %%
cols = [('Pclass', 'class'), ('Embarked', 'embark'), ('title', None)]

titanic = dummies(titanic, cols)

titanic.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Name', u'Sex', u'Age', u'SibSp',
#        u'Parch', u'Fare', u'class_1', u'class_2', u'class_3', u'embark_C',
#        u'embark_Q', u'embark_S', u'Master', u'Miss', u'Mr', u'Mrs',
#        u'Professional', u'Royalty'],
#       dtype='object')

# %% [markdown]
# ### Make the model

# %%
preX = titanic.drop(['Survived', 'Name', 'PassengerId'], axis = 1)

X = pd.DataFrame(MinMaxScaler().fit_transform(preX), columns = preX.columns)

y = titanic['Survived']

# %%
plt.figure(figsize = (12, 8))
corr_mat = np.tril(X.corr(), k=-1)
sns.heatmap(corr_mat, cmap = 'seismic')
plt.title('Titanic: Feature Correlations', fontsize = 24)
plt.xticks(np.arange(0.5, len(X.columns) + 0.5, 1), X.columns, fontsize = 14, rotation = 90)
plt.yticks(np.arange(0.5, len(X.columns) + 0.5, 1), list(X.columns)[::-1], fontsize = 14, rotation = 0)
plt.show()

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Drop a dummy from each set to avoid dummy variable trap:

# %%
X.drop(['class_3', 'embark_S', 'Mr'], axis = 1, inplace = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
parameters = {
    'penalty' : ['l1', 'l2'],
    'C' : [0.0001, 0.001, 0.01, 0.1, 0.5, 1, 5, 10, 20, 50]
    }   

model = linear_model.LogisticRegression(fit_intercept = True, n_jobs = -1, random_state = 42)
grid = GridSearchCV(estimator=model, param_grid = parameters)
grid.fit(X_train, y_train)
# summarize the results of the grid search
print 'accuracy: %s' %grid.best_score_ 
print grid.best_estimator_
# Out:
# accuracy: 0.830536912752
# LogisticRegression(C=20, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
## baseline accuracy:

len(titanic[titanic['Survived'] == 1])/float(len(titanic))
# Out:
# 0.3838383838383838

# %% [markdown]
# Our model is already performing remarkably better than random guessing.

# %%
selector = RFECV(grid.best_estimator_, step=1, cv=5)
selector.fit(X_train, y_train)
support = X.columns[selector.support_]
len(support)

if len(support) != len(X.columns):
    grid.fit(X_train[support], y_train)
    # summarize the results of the grid search
    print 'accuracy: %s' %grid.best_score_ 
    print grid.best_estimator_
    
else:
    print 'Recursive feature extraction CV chose to use all available features.'
# Out:
# Recursive feature extraction CV chose to use all available features.

# %%
grid = grid.best_estimator_

grid.fit(X_train, y_train)

grid.coef_
# Out:
# array([[-2.67902839, -1.41445909, -3.95756747, -2.10883761,  2.31943446,
#          1.68653386,  1.26174273,  0.81662196,  0.45521466,  3.35336764,
#          0.        ,  1.12954143, -0.44730921,  1.56146831]])

# %%
coefs = pd.DataFrame(grid.coef_).T
coefs.index = X.columns
coefs.columns = ['coef']
coefs['abs_coef'] = coefs['coef'].apply(lambda x: abs(x))
coefs = coefs.sort_values(by = 'abs_coef', ascending = False)
coefs['color'] = ['blue' if x < 0 else 'red' for x in coefs['coef']]

coefs
# Out:
#                   coef  abs_coef color
# SibSp        -3.957567  3.957567  blue
# Master        3.353368  3.353368   red
# Sex          -2.679028  2.679028  blue
# Fare          2.319434  2.319434   red
# Parch        -2.108838  2.108838  blue
# class_1       1.686534  1.686534   red
# Royalty       1.561468  1.561468   red
# Age          -1.414459  1.414459  blue
# class_2       1.261743  1.261743   red
# Mrs           1.129541  1.129541   red
# embark_C      0.816622  0.816622   red
# embark_Q      0.455215  0.455215   red
# Professional -0.447309  0.447309  blue
# Miss          0.000000  0.000000   red

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')
feature_set = X
N = len(feature_set.columns)
ind = np.arange(N)    # x locations
width = 0.4       # the width of the bars

plt.bar(ind, coefs['abs_coef'], width, color = coefs['color'], alpha = 0.5)

plt.title('Titanic Regressors: Feature Coefficient', fontsize = 24, y = 1.03)

plt.xlabel('Feature', fontsize = 20)
plt.xticks(ind + 0.18, coefs.index, fontsize = 14, rotation = 90)
plt.xlim([-0.5, len(feature_set.columns) + 0.5])

plt.ylabel('Coefficient', fontsize = 20)
plt.yticks(np.arange(0, 4.6, 0.5), fontsize = 14)
plt.ylim([-0.1, 4.6])

plt.grid(which='major', axis = 'x')

plt.axhline(0, linewidth = 2, color = 'black', alpha = 0.4)

plt.show()

# %%
y_pred = grid.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[153,  22],
#        [ 27,  93]])

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', labels=['Positive','Negative'], \
                          cmap=plt.cm.Blues):
    
    plt.figure(figsize=(12,8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    
    plt.grid(b = False)
    
    tick_marks = np.arange(2)
    plt.xticks(tick_marks, labels, fontsize = 18)
    plt.yticks(tick_marks, labels, rotation = 90, fontsize = 18)
        
    plt.title(title, fontsize = 24)
    plt.ylabel('True label', fontsize = 20)
    plt.xlabel('Predicted label', fontsize = 20)
    plt.tight_layout()
    
    width, height = cm.shape
    
    for x in xrange(width):
        for y in xrange(height):
            plt.annotate(str(cm[x][y]), xy=(y, x), 
                        horizontalalignment='center',
                        verticalalignment='center',
                        color = 'white',
                        fontsize=40).set_path_effects([path_effects.Stroke(linewidth=1, \
                            foreground='black'), path_effects.Normal()])
    return

# %%
plot_confusion_matrix(cm, title='Titanic: Survival Confusion Matrix', \
                      labels=['Survived', 'Died'], cmap=plt.cm.Greens)

# %%
print classification_report(y_test, y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.87      0.86       175
#           1       0.81      0.78      0.79       120
#
# avg / total       0.83      0.83      0.83       295

# %%
accuracies = []
precisions = []
recalls = []

for i in range(1, len(X.columns)):
    pick_em = SelectKBest(f_classif, k=i)
    pick_em.fit(X_train, y_train)
    support = X.columns[pick_em.get_support()]
    grid.fit(X_train[support], y_train)
    y_pred = grid.predict(X_test[support])
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    
results = pd.DataFrame(index = range(len(X.columns) - 1))
results['accuracy'] = accuracies
results['precision'] = precisions
results['recall'] = recalls

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

for i in [('precision', 'DarkOliveGreen'), ('accuracy', 'blue'), ('recall', 'Orange')]:
    plt.plot(results.index, results[i[0]], color = i[1], linewidth = 2.5, \
         label = i[0], alpha = 0.8)

plt.axhline(0, color='black', alpha = 0.6, linewidth = 1)
plt.axvline(0, color='black', alpha = 0.6, linewidth = 1)
plt.title('Titanic Passenger Data Set: Model Performance', fontsize = 24, y = 1.03)

# y label
plt.ylabel('Score', fontsize = 18)
plt.yticks(np.arange(0, 1.2, 0.1), fontsize = 12)

# x label
plt.xlabel('Number of Features in Model', y = 0.1, fontsize = 18)
plt.xticks(range(0, 70, 5), fontsize = 12)

plt.xlim([-0.1, len(X.columns)])
plt.ylim([0.49, 0.91])

# plt.axvline(9, color = 'red', alpha = 0.8, linewidth = 2, linestyle = 'dashed', \
#             label = '# features selected')

plt.legend(loc='center right', fontsize = 14)

plt.show()

# %% [markdown]
# ## Discussion

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The Titanic disaster remains one of the most tragic maritime accidents in modern history.  We have learned a number of things having explored the data set, namely that:
#
# * males were more likely to die than females;
# * older passengers were more likely to die than younger passengers;
# * first class/royalty passengers were more likely to survival than average passenger;
# * those passengers with family members and/or spouses aboard were more likely to die.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;We recommend that future attempts at disaster mitigation be designed with these points in mind.  Specifically, ensure that all locales are equipped with sufficiently many emergency devices so that people are not triaged based on gender, age, financial status, or number or family members they may be trying to help.

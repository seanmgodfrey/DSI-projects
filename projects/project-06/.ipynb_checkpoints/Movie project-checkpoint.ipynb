# %%
from IPython.core.display import Image
from imdbpie import Imdb
import pandas as pd
import plotly as pt
from matplotlib import pyplot as plt
import numpy as np
from sklearn import cross_validation, preprocessing
import time
import requests
import bs4
from bs4 import BeautifulSoup
import cPickle
import seaborn as sns
import re
from matplotlib import cm
from matplotlib.colors import ColorConverter

% matplotlib inline

# %%
# import statsmodels.api as st
# import sklearn
# from sklearn import linear_model as lm
# from sklearn import cross_validation, preprocessing
# import matplotlib.cm as cm
# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import roc_curve
# from sklearn.metrics import roc_auc_score
# from sklearn.cross_validation import train_test_split
# from sklearn.metrics import accuracy_score
# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score
# from sklearn.cross_validation import train_test_split
# from sklearn.cross_validation import cross_val_predict
# from sklearn.cross_validation import cross_val_score
# import matplotlib.patheffects as path_effects
# from sklearn.metrics import mean_squared_error

# %%
imdb = Imdb()
imdb = Imdb(anonymize=True)
imdb = Imdb(cache=True)

# %%
top = imdb.top_250()

# %%
top = pd.DataFrame(top)

# %%
len(top)
# Out:
# 250

# %%
top.head()
# Out:
#   can_rate                                              image  num_votes  \
# 0     True  {u'url': u'http://ia.media-imdb.com/images/M/M...    1679754
# 1     True  {u'url': u'http://ia.media-imdb.com/images/M/M...    1149267
# 2     True  {u'url': u'http://ia.media-imdb.com/images/M/M...     785960
# 3     True  {u'url': u'http://ia.media-imdb.com/images/M/M...    1664826
# 4     True  {u'url': u'http://ia.media-imdb.com/images/M/M...     859708
#
#    rating     tconst                     title     type  year
# 0     9.3  tt0111161  The Shawshank Redemption  feature  1994
# 1     9.2  tt0068646             The Godfather  feature  1972
# 2     9.0  tt0071562    The Godfather: Part II  feature  1974
# 3     9.0  tt0468569           The Dark Knight  feature  2008
# 4     8.9  tt0108052          Schindler's List  feature  1993

# %%
top['image'][0]
# Out:
# {u'height': 1388,
#  u'url': u'http://ia.media-imdb.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_.jpg',
#  u'width': 933}

# %%
del top['image']

# %%
top.dtypes
# Out:
# can_rate        bool
# num_votes      int64
# rating       float64
# tconst        object
# title         object
# type          object
# year          object
# dtype: object

# %%
top['can_rate'].value_counts()
# Out:
# True    250
# Name: can_rate, dtype: int64

# %%
del top['can_rate']

# %%
top['type'].value_counts()
# Out:
# feature    250
# Name: type, dtype: int64

# %%
del top['type']

# %%
top['year'] = top['year'].apply(lambda x: int(x))

# %%
top['num_votes'].describe()
# Out:
# count    2.500000e+02
# mean     4.033040e+05
# std      3.310266e+05
# min      2.507700e+04
# 25%      1.228830e+05
# 50%      3.235525e+05
# 75%      5.947172e+05
# max      1.679754e+06
# Name: num_votes, dtype: float64

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

df_hist = plt.hist(top['num_votes']/1000, color = 'darkred', bins = 30, alpha = 0.7)
plt.axvline(top['num_votes'].median()/1000, color='b', linestyle='dashed', linewidth=1.3, label = 'median')
plt.axvline(top['num_votes'].mean()/1000, color='g', linestyle='dashed', linewidth=1.3, label = 'mean')
plt.axhline(0, color='black')
plt.title('Histogram of Votes per Top 250 Movie', fontsize = 20, y = 1.05)

# y label
plt.ylabel('Frequency')

# x label
plt.xlabel('Number of Votes (x 1000)')

plt.xlim([0, max(top['num_votes']/1000)])
plt.ylim([0, 40])

plt.legend(loc='upper right', fontsize = 15)

plt.show()

# %% [markdown]
# Which movies have more than a million votes?

# %%
top[top['num_votes'] > 1000000][['title', 'year']].sort('year')
# Out:
# /Users/Rebecca/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning:
#
# sort(columns=....) is deprecated, use sort_values(by=.....)
#                                                 title  year
# 1                                       The Godfather  1972
# 0                            The Shawshank Redemption  1994
# 6                                        Pulp Fiction  1994
# 12                                       Forrest Gump  1994
# 21                                              Se7en  1995
# 9                                          Fight Club  1999
# 17                                         The Matrix  1999
# 10  The Lord of the Rings: The Fellowship of the Ring  2001
# 14              The Lord of the Rings: The Two Towers  2002
# 7       The Lord of the Rings: The Return of the King  2003
# 3                                     The Dark Knight  2008
# 13                                          Inception  2010
# 61                              The Dark Knight Rises  2012

# %%
top['rating'].describe()
# Out:
# count    250.000000
# mean       8.315200
# std        0.231133
# min        8.000000
# 25%        8.100000
# 50%        8.300000
# 75%        8.400000
# max        9.300000
# Name: rating, dtype: float64

# %% [markdown]
# Remember: minimum rating is so high because we're only looking at top 250 movies!

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

df_hist = plt.hist(top['rating'], color = 'dodgerblue', alpha = 0.5, bins = 30)
plt.axvline(top['rating'].median(), color='b', linestyle='dashed', linewidth=1.3, label = 'median')
plt.axvline(top['rating'].mean(), color='g', linestyle='dashed', linewidth=1.3, label = 'mean')
plt.axhline(0, color='black', alpha = 0.6)
plt.title('Histogram of Movie Rating (Top 250)', fontsize = 20, y = 1.05)

# y label
plt.ylabel('Frequency')

# x label
plt.xlabel('Rating')

plt.xlim([min(top['rating']), 10])
#plt.ylim([-10, 85])

plt.legend(loc='upper right', fontsize = 15)

plt.show()

# %%
top['year'].describe()
# Out:
# count     250.000000
# mean     1984.028000
# std        24.152361
# min      1921.000000
# 25%      1964.000000
# 50%      1991.000000
# 75%      2003.750000
# max      2016.000000
# Name: year, dtype: float64

# %% [markdown]
# In the histogram below, each bar slot represents one year:

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

df_hist = plt.hist(top['year'], color = 'burlywood', alpha = 0.8, bins = 95)
plt.axvline(top['year'].median(), color='b', linestyle='dashed', linewidth=1.3, label = 'median')
plt.axvline(top['year'].mean(), color='g', linestyle='dashed', linewidth=1.3, label = 'mean')
plt.axhline(0, color='black')
plt.title('Histogram of Movie Release Year (Top 250)', fontsize = 20)

# y label
plt.ylabel('Frequency')

# x label
plt.xlabel('Year')

plt.xlim([min(top['year']), max(top['year'])])
plt.ylim([0, 11.5])

plt.legend(loc='upper right', fontsize = 15)

plt.show()

# %% [markdown]
# 1957 was a good year:

# %%
top[top['year'] == 1957][['title', 'year']]
# Out:
#                             title  year
# 5                    12 Angry Men  1957
# 56                 Paths of Glory  1957
# 71    Witness for the Prosecution  1957
# 131  The Bridge on the River Kwai  1957
# 134              The Seventh Seal  1957
# 140             Wild Strawberries  1957
# 173             Nights of Cabiria  1957
# 245               Throne of Blood  1957

# %% [markdown]
# As was 1995:

# %%
top[top['year'] == 1995][['title', 'year']]
# Out:
#                   title  year
# 21                Se7en  1995
# 24   The Usual Suspects  1995
# 75           Braveheart  1995
# 91            Toy Story  1995
# 122                Heat  1995
# 138              Casino  1995
# 205      Before Sunrise  1995
# 219      Twelve Monkeys  1995
# 227            La Haine  1995

# %% [markdown]
# The spike farthest to the right on the histogram is combined 2015 and 2016-to-date:

# %%
top[(top['year'] == 2015) | (top['year'] == 2016)][['title', 'year']].sort('year')
# Out:
# /Users/Rebecca/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning:
#
# sort(columns=....) is deprecated, use sort_values(by=.....)
#                             title  year
# 118                    Inside Out  2015
# 123                          Room  2015
# 141  Star Wars: The Force Awakens  2015
# 180                     Spotlight  2015
# 183            Mad Max: Fury Road  2015
# 213                  The Revenant  2015
# 232                   The Martian  2015
# 159    Captain America: Civil War  2016
# 178                      Zootopia  2016
# 203                      Deadpool  2016

# %%
top_scaled = preprocessing.scale(top[['num_votes', 'rating', 'year']])
top_scaled = pd.DataFrame(top_scaled, columns = ['num_votes', 'rating', 'year'])

# %%
sns.pairplot(top_scaled)

# %% [markdown]
# Let's dig a little deeper into these plots...
#
# We'll use 'rating' to assign the area of points on a scatterplot of number of votes vs. year of movie release.  If we just try dividing by a constant, the difference in size is not readily apparent, so let's try normalizing!

# %%
top_scaled['rating'].describe()
# Out:
# count    2.500000e+02
# mean     3.674838e-15
# std      1.002006e+00
# min     -1.366450e+00
# 25%     -9.329318e-01
# 50%     -6.589481e-02
# 75%      3.676237e-01
# max      4.269290e+00
# Name: rating, dtype: float64

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

df_hist = plt.hist(top_scaled['rating'], color = 'dodgerblue', alpha = 0.5, bins = 30)
plt.axvline(top_scaled['rating'].median(), color='b', linestyle='dashed', linewidth=1.3, label = 'median')
plt.axvline(top_scaled['rating'].mean(), color='g', linestyle='dashed', linewidth=1.3, label = 'mean')
plt.axhline(0, color='black')
plt.title('Histogram of Standardized Movie Ratings (Top 250)', fontsize = 20)

# y label
plt.ylabel('Frequency')

# x label
plt.xlabel('Standardized Rating')

plt.xlim([min(top_scaled['rating']), max(top_scaled['rating'])])
#plt.ylim([-10, 85])

plt.legend(loc='upper right', fontsize = 15)

plt.show()

# %% [markdown]
# If we use the standardized ratings multiplied by a constant, though, we'll have a negative area assigned to everything under the mean!  Can't have that.  Let's add a little more than the minimum value to every standardized rating and then multiply by a constant:

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

area = (top_scaled['rating'] + 1.4)*30

plt.scatter(top['year'], top['num_votes']/1000000, color = 'darkgreen', alpha = 0.5, s = area, \
            label = 'number of votes')

plt.title('Number of Votes by Year of Movie Release (Top 250)', fontsize = 22)
plt.axhline(0, color='black', alpha = 0.5)
plt.axvline(2016, color='b', linestyle='dashed', alpha = 0.7, linewidth=0.8, label = 'current year (2016)')

# y label
plt.ylabel('Number of Votes (x 1 million)')

# x label
plt.xlabel('Year of Release')

# set the figure boundaries
plt.xlim([min(top['year'])-5, 2020])
plt.ylim([0, 2.2])
plt.grid(True)
plt.legend(loc='upper right', fontsize = 12)
plt.annotate('**area of points is proportional to rating', (1,0), (-200, -20), \
             xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 12)
plt.show()

# %%
top_scaled['year'].describe()
# Out:
# count    2.500000e+02
# mean    -8.291146e-16
# std      1.002006e+00
# min     -2.614835e+00
# 25%     -8.308991e-01
# 50%      2.892465e-01
# 75%      8.182042e-01
# max      1.326418e+00
# Name: year, dtype: float64

# %% [markdown]
# The plot below is not as 'nice-looking' as the previous one; let's scrape imdb.com to find some more variables!

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

# def rand_jitter(arr):
#     stdev = .005*(max(arr)-min(arr))
#     return arr + np.random.randn(len(arr)) * stdev

# def jitter(x, y, s=10, marker='o', cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, \
#            verts=None, hold=None, **kwargs):
#     return plt.scatter(rand_jitter(x), rand_jitter(y), s=s, marker=marker, cmap=cmap, norm=norm, vmin=vmin, \
#                        vmax=vmax, alpha=alpha, linewidths=linewidths, verts=verts, hold=hold, **kwargs)
#jitter(top['num_votes']/1000000, top['rating'], color = 'purple', alpha = 0.5, s = area)

area = (top_scaled['year'] + 3)*15

plt.scatter(top['num_votes']/1000000, top['rating'], color = 'purple', alpha = 0.5, s = area)

plt.title('Number of Votes by Year of Movie Release (Top 250)', fontsize = 22)
plt.axhline(0, color='darkblue', alpha = 0.5)
# y label
plt.ylabel('Rating (/10)')

# x label
plt.xlabel('Number of Votes (x 1 million)')

# set the figure boundaries
plt.xlim([-0.05, 2])
plt.ylim([7.9, 9.5])
plt.grid(True)

m, b = np.polyfit(top['num_votes']/1000000, top['rating'], 1)

plt.plot(top['num_votes']/1000000, m*top['num_votes']/1000000 + b, '-', linewidth = 0.7)

plt.annotate('**area of points is proportional to year of release', (1,0), (-200, -20), \
             xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 12)
plt.show()

## jitter assistance from:
## http://stackoverflow.com/questions/8671808/matplotlib-avoiding-overlapping-datapoints-in-a-scatter-dot-beeswarm-plot

# %% [markdown]
# Let's use an API to get what we can:

# %%
# certification = []
# for movie in top['tconst']:
#     time.sleep(1)
#     title = imdb.get_title_by_id(movie)
#     cert = title.certification
#     certification.append(cert)
    
# if len(certification) == 250:
#     certification = pd.DataFrame(certification, columns = ['cert'])
#     certification.to_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/certification.csv', index = False)
#     top['cert'] = certification
# else:
#     print 'Uh oh!  We didn\'t get 250 observations!  There are %s instead :(' %len(certification)

# %%
certification = pd.read_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/certification.csv')
certification.columns = ['cert']
top['cert'] = certification

# %%
top['cert'].value_counts()
# Out:
# R            92
# Not Rated    33
# PG           32
# PG-13        30
# Approved     14
# Unrated      12
# G            10
# TV-PG         9
# TV-14         6
# TV-MA         4
# Passed        3
# M             2
# X             1
# TV-G          1
# E             1
# Name: cert, dtype: int64

# %% [markdown]
# Let's consolidate these as much as possible.  Examine (imdb.com, wikipedia) each certification except 'R', 'PG', 'PG-13', 'G'.  We'll assume those have been categorized properly.  Update if necessary.

# %%
top['cert'][101] = 'PG-13' # Indiana Jones and the Last Crusade
top['cert'][91] = 'G' # Toy Story
top['cert'][78] = 'R' # A Clockwork Orange
top['cert'][34] = 'G' # City Lights
top['cert'][80] = 'Not Rated' # Double Indemnity
top['cert'][215] = 'G' # Wizard of Oz 
top['cert'][27] = 'PG-13' # Once Upon a Time in the West
top['cert'][241] = 'R' # A Fistful of Dollars
top['cert'][9] = 'R' # Fight Club
top['cert'][29] = 'R' # Saving Private Ryan
top['cert'][74] = 'R' # Reservoir Dogs
top['cert'][96] = 'R' # L.A. Confidential
top['cert'][30] = 'R' # American History X
top['cert'][40] = 'R' # Terminator 2: Judgment Day
top['cert'][52] = 'R' # Alien
top['cert'][64] = 'PG-13' # Princess Mononoke
top['cert'][100] = 'R' # Scarface
top['cert'][145] = 'Not Rated' # Judgment at Nuremberg
top['cert'][18] = 'Not Rated' # Seven Samurai
top['cert'][26] = 'R' # Léon: The Professional
top['cert'][59] = 'Not Rated' # Grave of the Fireflies
top['cert'][77] = 'R' # Requiem for a Dream
top['cert'][99] = 'Not Rated' # Rashomon
top['cert'][106] = 'Not Rated' # Yojimbo
top['cert'][139] = 'Not Rated' # The General
top['cert'][140] = 'Not Rated' # Wild Strawberries
top['cert'][171] = 'Not Rated' # It Happened One Night
top['cert'][209] = 'Not Rated' # Diabolique
top['cert'][210] = 'Not Rated' # Memories of Murder
top['cert'][245] = 'Not Rated' # Throne of Blood
top['cert'][32] = 'PG' # Casablanca
top['cert'][104] = 'Approved' # All About Eve
top['cert'][109] = 'Not Rated' # The Treasure of the Sierra Madre
top['cert'][137] = 'PG' # Howl's Moving Castle
top['cert'][158] = 'G' # Gone With the Wind
top['cert'][196] = 'G' # Ben-Hur
top['cert'][216] = 'G' # Monsters, Inc.
top['cert'][223] = 'PG' # Strangers on a Train
top['cert'][242] = 'PG' # Castle in the Sky
top['cert'][23] = 'PG' # It's a Wonderful Life
top['cert'][33] = 'R' # Psycho
top['cert'][39] = 'PG' # Rear Window
top['cert'][50] = 'PG' # Dr. Strangelove
top['cert'][70] = 'PG' # Vertigo
top['cert'][131] = 'PG' # Bridge on the River Kwai

# %% [markdown]
# Muuuuuch nicer:

# %%
top['cert'].value_counts()
# Out:
# R            105
# Not Rated     46
# PG            41
# PG-13         33
# G             16
# Approved       9
# Name: cert, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

# subset dataframe by certification
top_R = top[top['cert'] == 'R']
top_NR = top[top['cert'] == 'Not Rated']
top_PG = top[top['cert'] == 'PG']
top_PG13 = top[top['cert'] == 'PG-13']
top_G = top[top['cert'] == 'G']
top_Approved = top[top['cert'] == 'Approved']

# assign colors to ranked certifications
cert = ['G', 'PG', 'PG-13', 'R']
cert_colors = []
for i in range(0, 256, 256/3):
    cert_colors.append(cm.coolwarm(i))
cert_dict = dict(zip(cert, cert_colors))

# set area of dot proportional-ish to rating
area = (top_scaled['rating'] + 1.4)*30

# plot number of votes by year of release
plt.scatter(top_R['year'], top_R['num_votes']/1000000, color = cert_dict['R'], alpha = 0.5, s = area, label = 'R')
plt.scatter(top_PG13['year'], top_PG13['num_votes']/1000000, color = cert_dict['PG-13'], alpha = 0.5, s = area, \
            label = 'PG-13')
plt.scatter(top_PG['year'], top_PG['num_votes']/1000000, color = cert_dict['PG'], alpha = 0.5, s = area, label = 'PG')
plt.scatter(top_G['year'], top_G['num_votes']/1000000, color = cert_dict['G'], alpha = 0.5, s = area, label = 'G')
plt.scatter(top_Approved['year'], top_Approved['num_votes']/1000000, color = 'darkgreen', alpha = 0.5, s = area, \
            label = 'Approved')
plt.scatter(top_NR['year'], top_NR['num_votes']/1000000, color = 'black', alpha = 0.3, s = area, label = 'No Rating')

plt.title('Number of Votes by Year of Movie Release (Top 250)', fontsize = 22)

# add x-axis line and a line to show current year
plt.axhline(0, color='black', alpha = 0.6)
plt.axvline(2016, color='black', linestyle='dashed', linewidth=0.8, label = 'current year (2016)')

# y label
plt.ylabel('Number of Votes (x 1 million)')

# x label
plt.xlabel('Year of Release')

# set the figure boundaries
plt.xlim([min(top['year'])-5, 2020])
plt.ylim([0, 2.5])

plt.grid(True)
plt.legend(loc='upper right', fontsize = 12)
plt.annotate('**area of points is proportional to rating', (1,0), (-200, -20), \
             xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 12)
plt.show()

# %%
top.head(1)
# Out:
#    num_votes  rating     tconst                     title  year cert
# 0    1679754     9.3  tt0111161  The Shawshank Redemption  1994    R

# %%
top = top[['tconst', 'title', 'year', 'cert', 'rating', 'num_votes']]

# %%
# cast = []
# for movie in top['tconst']:
#     lil_cast = []
#     time.sleep(2)
#     title = imdb.get_title_by_id(movie)
#     creds = title.credits
#     for i in [0, 1, 2]:
#         lil_cast.append(creds[i])
#     cast.append(lil_cast)

# len(cast)

# %%
# cast = pd.DataFrame(cast)
# cast.to_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/cast.csv', index = False)
# top['cast'] = cast

# %% [markdown]
# OK!  Enough of that... now let's use scraped data.  To perform the scrape, uncomment and run cell below; otherwise, load from file in the following cell:

# %%
# URL = 'http://www.imdb.com/title/'
# paths = top['tconst']
# soup = []
# for i in paths:
#     time.sleep(1)
#     request = requests.get(URL + i + '/')
#     if str(request) != '<Response [200]>':
#         print URL + i + '/'
#     tiny_soup = BeautifulSoup(request.content, "lxml")
#     soup.append(tiny_soup)

# cPickle.dump(soup, open('movie_soup.p', 'wb'))

# %%
soup = cPickle.load(open('/Users/Rebecca/DSI-projects/projects/project-06/assets/movie_soup.p', 'rb'))

# %%
# running_time = []
# for i in range(len(soup)):
#     times = []
#     for j in soup[i].find_all('time', itemprop = 'duration'):
#         times.append(j.text.encode('utf8'))
#     running_time.append(times[0])
#
# for i in range(len(running_time)):
#     split_time = []
#     clean_time = running_time[i].replace('\n                        ', '')
#     clean_time = clean_time.replace('min\n                    ', '')
#     split_time = clean_time.split('h ')
#     split_time[0] = split_time[0].replace('h\n                    ', '')
#     if len(split_time) == 1:
#         minutes = float(split_time[0]) * 60
#         running_time[i] = int(minutes) 
#     else:
#         minutes = float(split_time[0]) * 60 + float(split_time[1])
#         running_time[i] = int(minutes)
        
# run_time = pd.DataFrame(running_time, columns = ['run_time'])
# run_time.to_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/run_time.csv', index = False)

# %%
run_time = pd.read_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/run_time.csv')
top['run_time'] = run_time

# %%
# genre = []
# for i in range(len(soup)):
#     genres = []
#     for j in soup[i].find_all('span', itemprop = 'genre'):
#         genres.append(j.text.encode('utf8'))
#     genre.append(genres)

# for i in range(len(genre)):
#     genre[i] = str(genre[i])
    
# genre = pd.DataFrame(genre, columns = ['genre])
# genre.to_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/genre.csv', index = False)

# %%
genre = pd.read_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/genre.csv')
genre.columns = ['genre']
top['genre'] = genre

# %%
# release_info = []
# for i in range(len(soup)):
#     info = []
#     for j in soup[i].find_all('a', title = 'See more release dates'):
#         info.append(j.text.encode('utf8'))
#     release_info.append(info)

# month = []
# country = []
# for i in range(len(release_info)):
#     month_country = []
#     release_info[i] = str(release_info[i])
#     clean = release_info[i].replace(')\\n\\n\']', '')
#     split = clean.split(' ')
#     if len(split) == 4:
#         month.append(split[1])
#         split[3] = split[3].replace('(', '')
#         country.append(split[3])
#     else:
#         month.append(split)
#         country.append(split)

# all_months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', \
#              'November', 'December']

# for i in range(len(top)):
#     if top['month'][i] in all_months:
#         continue
#     else:
#         print top.loc[i]
#         print '\n'

# %% [markdown]
# Correct the ones that came through in different format and look up month for 'The Gold Rush' (thanks, Wikipedia!):

# %%
# top['month'][5] = 'April'
# top['country'][5] = 'USA'
# top['month'][56] = 'October'
# top['country'][56] = 'West Germany'
# top['month'][65] = 'November'
# top['country'][65] = 'South Korea'
# top['month'][129] = 'June'
# top['country'][129] = 'Germany'
# top['month'][210] = 'May'
# top['country'][210] = 'South Korea'
# top['month'][224] = 'December'
# top['country'][224] = 'Hong Kong'

# %%
# top['country'].value_counts()
# Out:
# USA             203
# UK               10
# Japan             8
# France            6
# Sweden            4
# Australia         2
# Argentina         2
# South Korea       2
# Hong Kong         1
# Singapore         1
# China             1
# Iran              1
# Netherlands       1
# India             1
# West Germany      1
# Philippines       1
# Denmark           1
# Hungary           1
# Germany           1
# Italy             1
# Brazil            1
# Name: country, dtype: int64

# %% [markdown]
# Hey, I know!  Let's practice using dictionaries.  We'll make a bar plot of movie counts by month and put the bars in order of month (not in order of count):

# %%
y = pd.DataFrame(top['month'].value_counts())
y.columns = ['count']
y['month'] = y.index
y = y.reset_index(drop = True)
order = range(12)
all_months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', \
              'November', 'December']
month_dict = dict(zip(all_months, order))
y['order'] = y['month'].apply(lambda x: month_dict[x])
y = y.sort('order')
del y['order']
y = y.set_index(y['month'], drop = False)
del y['month']
# Out:
# /Users/Rebecca/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning:
#
# sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')

y['count'].plot.bar(color = 'thistle')

plt.title('Top 250 Movies by Month of Release', fontsize = 20)

# y label
plt.ylabel('Number of Movies', fontsize = 18)

# x label
plt.xlabel('Month', fontsize = 18)
plt.axhline(0, color='black', alpha = 0.6)
plt.xticks(rotation=70, fontsize = 13)
plt.show()

# %%
# month = pd.DataFrame(top['month'], columns = ['month'])
# country = pd.DataFrame(top['country'], columns = ['country'])
# month.to_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/month.csv', index = False)
# country.to_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/country.csv', index = False)

# %%
month = pd.read_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/month.csv')
country = pd.read_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/country.csv')
top['month'] = month
top['country'] = country

# %% [markdown]
# Let's check out where non-USA, non-UK movies are from:

# %%
top[(top['country'] != 'USA') & (top['country'] != 'UK')][['title', 'country']]

# %% [markdown]
# A lot of these look weird... Hitchcock in Japan and Brazil?  Reservoir Dogs in France?  They must be the release locations.  Let's scrape country of origin separately and keep this as-is for now.

# %%
# origin = []
# for i in range(len(soup)):
#     country = []
#     for j in soup[i].find_all('a', href = re.compile('/country/')):
#         country.append(j.text.encode('utf8'))
#     if len(country) > 1:
#         mini_list = []
#         mini_list.append(country[0])
#         origin.append(mini_list)
#     else:
#         origin.append(country)

# origin = pd.DataFrame(origin)
# origin.to_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/origin.csv', index = False)

# %%
origin = pd.read_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/origin.csv')
top['origin'] = origin

# %%
for i in range(len(top)):
    if top['country'][i] != top['origin'][i]:
        print top.loc[i]
# Out:
# tconst                            tt0060196
# title        The Good, the Bad and the Ugly
# year                                   1966
# cert                              Not Rated
# rating                                  8.9
# num_votes                            500519
# run_time                                161
# genre                           ['Western']
# month                              December
# country                                 USA
# origin                                Italy
# director                       Sergio Leone
# Name: 8, dtype: object
# tconst                                               tt0120737
# title        The Lord of the Rings: The Fellowship of the Ring
# year                                                      2001
# cert                                                     PG-13
# rating                                                     8.8
# num_votes                                              1231879
# run_time                                                   178
# genre                         ['Action', 'Adventure', 'Drama']
# month                                                 December
# country                                                    USA
# origin                                             New Zealand
# director                                         Peter Jackson
# Name: 10, dtype: object
# tconst                              tt0047478
# title                           Seven Samurai
# year                                     1954
# cert                                Not Rated
# rating                                    8.7
# num_votes                              227818
# run_time                                  207
# genre        ['Action', 'Adventure', 'Drama']
# month                                November
# country                                   USA
# origin                                  Japan
# director                       Akira Kurosawa
# Name: 18, dtype: object
# tconst                tt0317248
# title               City of God
# year                       2002
# cert                          R
# rating                      8.7
# num_votes                530326
# run_time                    130
# genre        ['Crime', 'Drama']
# month                  February
# country                     USA
# origin                   Brazil
# director     Fernando Meirelles
# Name: 20, dtype: object
# tconst                            tt0118799
# title                     Life Is Beautiful
# year                                   1997
# cert                                  PG-13
# rating                                  8.6
# num_votes                            417029
# run_time                                116
# genre        ['Comedy', 'Drama', 'Romance']
# month                              February
# country                                 USA
# origin                                Italy
# director                    Roberto Benigni
# Name: 25, dtype: object
# tconst                            tt0110413
# title                Léon: The Professional
# year                                   1994
# cert                                      R
# rating                                  8.6
# num_votes                            721030
# run_time                                110
# genre        ['Crime', 'Drama', 'Thriller']
# month                              November
# country                                 USA
# origin                               France
# director                         Luc Besson
# Name: 26, dtype: object
# tconst                          tt0064116
# title        Once Upon a Time in the West
# year                                 1968
# cert                                PG-13
# rating                                8.6
# num_votes                          214732
# run_time                              175
# genre                         ['Western']
# month                                July
# country                               USA
# origin                              Italy
# director                     Sergio Leone
# Name: 27, dtype: object
# tconst                                  tt0245429
# title                               Spirited Away
# year                                         2001
# cert                                           PG
# rating                                        8.6
# num_votes                                  414735
# run_time                                      125
# genre        ['Animation', 'Adventure', 'Family']
# month                                       March
# country                                       USA
# origin                                      Japan
# director                           Hayao Miyazaki
# Name: 28, dtype: object
# tconst                     tt0047396
# title                    Rear Window
# year                            1954
# cert                              PG
# rating                           8.5
# num_votes                     314175
# run_time                         112
# genre        ['Mystery', 'Thriller']
# month                         August
# country                           UK
# origin                           USA
# director            Alfred Hitchcock
# Name: 39, dtype: object
# tconst                           tt0253474
# title                          The Pianist
# year                                  2002
# cert                                     R
# rating                                 8.5
# num_votes                           494653
# run_time                               150
# genre        ['Biography', 'Drama', 'War']
# month                                March
# country                                USA
# origin                              France
# director                    Roman Polanski
# Name: 42, dtype: object
# tconst                tt2582802
# title                  Whiplash
# year                       2014
# cert                          R
# rating                      8.5
# num_votes                393228
# run_time                    107
# genre        ['Drama', 'Music']
# month                   October
# country             Philippines
# origin                      USA
# director        Damien Chazelle
# Name: 44, dtype: object
# tconst                               tt0043014
# title                             Sunset Blvd.
# year                                      1950
# cert                                 Not Rated
# rating                                     8.5
# num_votes                               138742
# run_time                                   110
# genre        ['Drama', 'Film-Noir', 'Romance']
# month                                September
# country                              Australia
# origin                                     USA
# director                          Billy Wilder
# Name: 51, dtype: object
# tconst                              tt0405094
# title                     The Lives of Others
# year                                     2006
# cert                                        R
# rating                                    8.5
# num_votes                              257879
# run_time                                  137
# genre                   ['Drama', 'Thriller']
# month                                   March
# country                                   USA
# origin                                Germany
# director     Florian Henckel von Donnersmarck
# Name: 54, dtype: object
# tconst                tt0095765
# title           Cinema Paradiso
# year                       1988
# cert                         PG
# rating                      8.5
# num_votes                151319
# run_time                    155
# genre                 ['Drama']
# month                  February
# country                     USA
# origin                    Italy
# director     Giuseppe Tornatore
# Name: 55, dtype: object
# tconst              tt0050825
# title          Paths of Glory
# year                     1957
# cert                 Approved
# rating                    8.5
# num_votes              120265
# run_time                   88
# genre        ['Drama', 'War']
# month                 October
# country          West Germany
# origin                    USA
# director      Stanley Kubrick
# Name: 56, dtype: object
# tconst                         tt0087843
# title        Once Upon a Time in America
# year                                1984
# cert                                   R
# rating                               8.4
# num_votes                         219626
# run_time                             229
# genre                 ['Crime', 'Drama']
# month                               June
# country                              USA
# origin                             Italy
# director                    Sergio Leone
# Name: 67, dtype: object
# tconst                              tt0053125
# title                      North by Northwest
# year                                     1959
# cert                                 Approved
# rating                                    8.4
# num_votes                              219214
# run_time                                  136
# genre        ['Action', 'Adventure', 'Crime']
# month                               September
# country                                 Japan
# origin                                    USA
# director                     Alfred Hitchcock
# Name: 68, dtype: object
# tconst                                tt0082096
# title                                  Das Boot
# year                                       1981
# cert                                          R
# rating                                      8.4
# num_votes                                167341
# run_time                                    149
# genre        ['Adventure', 'Drama', 'Thriller']
# month                                  February
# country                                     USA
# origin                             West Germany
# director                      Wolfgang Petersen
# Name: 69, dtype: object
# tconst                                tt0052357
# title                                   Vertigo
# year                                       1958
# cert                                         PG
# rating                                      8.4
# num_votes                                247237
# run_time                                    128
# genre        ['Mystery', 'Romance', 'Thriller']
# month                                      July
# country                                  Brazil
# origin                                      USA
# director                       Alfred Hitchcock
# Name: 70, dtype: object
# tconst                           tt0022100
# title                                    M
# year                                  1931
# cert                             Not Rated
# rating                                 8.4
# num_votes                            98498
# run_time                                99
# genre        ['Crime', 'Drama', 'Mystery']
# month                               August
# country                             Sweden
# origin                             Germany
# director                        Fritz Lang
# Name: 73, dtype: object
# tconst                            tt0105236
# title                        Reservoir Dogs
# year                                   1992
# cert                                      R
# rating                                  8.4
# num_votes                            660382
# run_time                                 99
# genre        ['Crime', 'Drama', 'Thriller']
# month                             September
# country                              France
# origin                                  USA
# director                  Quentin Tarantino
# Name: 74, dtype: object
# tconst                   tt0211915
# title                       Amélie
# year                          2001
# cert                             R
# rating                         8.4
# num_votes                   531220
# run_time                       122
# genre        ['Comedy', 'Romance']
# month                     February
# country                        USA
# origin                      France
# director        Jean-Pierre Jeunet
# Name: 76, dtype: object
# tconst                          tt0066921
# title                  A Clockwork Orange
# year                                 1971
# cert                                    R
# rating                                8.4
# num_votes                          554739
# run_time                              136
# genre        ['Crime', 'Drama', 'Sci-Fi']
# month                            February
# country                               USA
# origin                                 UK
# director                  Stanley Kubrick
# Name: 78, dtype: object
# tconst               tt0093058
# title        Full Metal Jacket
# year                      1987
# cert                         R
# rating                     8.3
# num_votes               481949
# run_time                   116
# genre         ['Drama', 'War']
# month                     July
# country                    USA
# origin                      UK
# director       Stanley Kubrick
# Name: 86, dtype: object
# tconst                          tt0070735
# title                           The Sting
# year                                 1973
# cert                                   PG
# rating                                8.3
# num_votes                          174530
# run_time                              129
# genre        ['Comedy', 'Crime', 'Drama']
# month                            December
# country                                UK
# origin                                USA
# director                  George Roy Hill
# Name: 87, dtype: object
# tconst              tt0040522
# title         Bicycle Thieves
# year                     1948
# cert                Not Rated
# rating                    8.3
# num_votes               93831
# run_time                   89
# genre               ['Drama']
# month                December
# country                   USA
# origin                  Italy
# director     Vittorio De Sica
# Name: 89, dtype: object
# tconst                 tt0208092
# title                     Snatch
# year                        2000
# cert                           R
# rating                       8.3
# num_votes                 597750
# run_time                     102
# genre        ['Comedy', 'Crime']
# month                    January
# country                      USA
# origin                        UK
# director             Guy Ritchie
# Name: 92, dtype: object
# tconst                    tt0059578
# title        For a Few Dollars More
# year                           1965
# cert                       Approved
# rating                          8.3
# num_votes                    156134
# run_time                        132
# genre                   ['Western']
# month                           May
# country                         USA
# origin                        Italy
# director               Sergio Leone
# Name: 97, dtype: object
# tconst                tt0042876
# title                  Rashomon
# year                       1950
# cert                   Approved
# rating                      8.3
# num_votes                101912
# run_time                     88
# genre        ['Crime', 'Drama']
# month                  December
# country                     USA
# origin                    Japan
# director         Akira Kurosawa
# Name: 98, dtype: object
# tconst                            tt0053604
# title                         The Apartment
# year                                   1960
# cert                              Not Rated
# rating                                  8.3
# num_votes                            108656
# run_time                                125
# genre        ['Comedy', 'Drama', 'Romance']
# month                             September
# country                              France
# origin                                  USA
# director                       Billy Wilder
# Name: 99, dtype: object
# tconst                 tt0017136
# title                 Metropolis
# year                        1927
# cert                   Not Rated
# rating                       8.3
# num_votes                 111196
# run_time                     153
# genre        ['Drama', 'Sci-Fi']
# month                      March
# country                      USA
# origin                   Germany
# director              Fritz Lang
# Name: 103, dtype: object
# tconst                  tt0042192
# title               All About Eve
# year                         1950
# cert                     Approved
# rating                        8.3
# num_votes                   82526
# run_time                      138
# genre                   ['Drama']
# month                     January
# country                    Sweden
# origin                        USA
# director     Joseph L. Mankiewicz
# Name: 104, dtype: object
# tconst                             tt0055630
# title                                Yojimbo
# year                                    1961
# cert                               Not Rated
# rating                                   8.3
# num_votes                              73594
# run_time                                 110
# genre        ['Comedy', 'Drama', 'Thriller']
# month                              September
# country                                  USA
# origin                                 Japan
# director                      Akira Kurosawa
# Name: 106, dtype: object
# tconst                              tt0053291
# title                        Some Like It Hot
# year                                     1959
# cert                                Not Rated
# rating                                    8.3
# num_votes                              174229
# run_time                                  120
# genre        ['Adventure', 'Comedy', 'Crime']
# month                                   April
# country                                 Japan
# origin                                    USA
# director                         Billy Wilder
# Name: 111, dtype: object
# tconst                 tt0118849
# title         Children of Heaven
# year                        1997
# cert                          PG
# rating                       8.5
# num_votes                  27191
# run_time                      89
# genre        ['Drama', 'Family']
# month                    January
# country                      USA
# origin                      Iran
# director            Majid Majidi
# Name: 115, dtype: object
# tconst                               tt0363163
# title                                 Downfall
# year                                      2004
# cert                                         R
# rating                                     8.3
# num_votes                               247076
# run_time                                   156
# genre        ['Biography', 'Drama', 'History']
# month                                    April
# country                                    USA
# origin                                 Germany
# director                   Oliver Hirschbiegel
# Name: 117, dtype: object
# tconst              tt3170832
# title                    Room
# year                     2015
# cert                        R
# rating                    8.3
# num_votes              153958
# run_time                  118
# genre               ['Drama']
# month                 January
# country                   USA
# origin                Ireland
# director     Lenny Abrahamson
# Name: 123, dtype: object
# tconst                         tt0457430
# title                    Pan's Labyrinth
# year                                2006
# cert                                   R
# rating                               8.2
# num_votes                         464816
# run_time                             118
# genre        ['Drama', 'Fantasy', 'War']
# month                            January
# country                              USA
# origin                             Spain
# director              Guillermo del Toro
# Name: 124, dtype: object
# tconst            tt0044741
# title                 Ikiru
# year                   1952
# cert              Not Rated
# rating                  8.3
# num_votes             41950
# run_time                143
# genre             ['Drama']
# month                 March
# country                 USA
# origin                Japan
# director     Akira Kurosawa
# Name: 127, dtype: object
# tconst                              tt0015864
# title                           The Gold Rush
# year                                     1925
# cert                                Not Rated
# rating                                    8.3
# num_votes                               67356
# run_time                                   95
# genre        ['Adventure', 'Comedy', 'Drama']
# month                                    June
# country                               Germany
# origin                                    USA
# director                      Charles Chaplin
# Name: 129, dtype: object
# tconst                           tt0050212
# title         The Bridge on the River Kwai
# year                                  1957
# cert                                    PG
# rating                                 8.2
# num_votes                           148470
# run_time                               161
# genre        ['Adventure', 'Drama', 'War']
# month                             December
# country                                USA
# origin                                  UK
# director                        David Lean
# Name: 131, dtype: object
# tconst                              tt1305806
# title                The Secret in Their Eyes
# year                                     2009
# cert                                        R
# rating                                    8.2
# num_votes                              130737
# run_time                                  129
# genre        ['Drama', 'Mystery', 'Thriller']
# month                                     May
# country                                   USA
# origin                              Argentina
# director                 Juan José Campanella
# Name: 132, dtype: object
# tconst                  tt0050976
# title            The Seventh Seal
# year                         1957
# cert                    Not Rated
# rating                        8.2
# num_votes                  111202
# run_time                       96
# genre        ['Drama', 'Fantasy']
# month                     October
# country                       USA
# origin                     Sweden
# director           Ingmar Bergman
# Name: 134, dtype: object
# tconst                                  tt0347149
# title                        Howl's Moving Castle
# year                                         2004
# cert                                           PG
# rating                                        8.2
# num_votes                                  212473
# run_time                                      119
# genre        ['Animation', 'Adventure', 'Family']
# month                                        June
# country                                       USA
# origin                                      Japan
# director                           Hayao Miyazaki
# Name: 137, dtype: object
# tconst                               tt0017925
# title                              The General
# year                                      1926
# cert                                 Not Rated
# rating                                     8.2
# num_votes                                53212
# run_time                                    67
# genre        ['Action', 'Adventure', 'Comedy']
# month                                 February
# country                                 France
# origin                                     USA
# director                        Clyde Bruckman
# Name: 139, dtype: object
# tconst                  tt0050986
# title           Wild Strawberries
# year                         1957
# cert                    Not Rated
# rating                        8.2
# num_votes                   62723
# run_time                       91
# genre        ['Drama', 'Romance']
# month                        June
# country                       USA
# origin                     Sweden
# director           Ingmar Bergman
# Name: 140, dtype: object
# tconst                   tt0055031
# title        Judgment at Nuremberg
# year                          1961
# cert                     Not Rated
# rating                         8.3
# num_votes                    44066
# run_time                       186
# genre             ['Drama', 'War']
# month                     December
# country                     Sweden
# origin                         USA
# director            Stanley Kramer
# Name: 145, dtype: object
# tconst          tt0046438
# title         Tokyo Story
# year                 1953
# cert            Not Rated
# rating                8.3
# num_votes           26171
# run_time              136
# genre           ['Drama']
# month               March
# country               USA
# origin              Japan
# director     Yasujirô Ozu
# Name: 147, dtype: object
# tconst                         tt1255953
# title                          Incendies
# year                                2010
# cert                                   R
# rating                               8.2
# num_votes                          79636
# run_time                             139
# genre        ['Drama', 'Mystery', 'War']
# month                            January
# country                           France
# origin                            Canada
# director                Denis Villeneuve
# Name: 149, dtype: object
# tconst                                 tt0074896
# title                                The Message
# year                                        1976
# cert                                          PG
# rating                                       8.5
# num_votes                                  28951
# run_time                                     177
# genre        ['Adventure', 'Biography', 'Drama']
# month                                       July
# country                                   France
# origin                                   Lebanon
# director                         Moustapha Akkad
# Name: 152, dtype: object
# tconst              tt0077416
# title         The Deer Hunter
# year                     1978
# cert                        R
# rating                    8.2
# num_votes              231297
# run_time                  183
# genre        ['Drama', 'War']
# month                February
# country                   USA
# origin                     UK
# director       Michael Cimino
# Name: 153, dtype: object
# tconst           tt0117951
# title        Trainspotting
# year                  1996
# cert                     R
# rating                 8.2
# num_votes           466574
# run_time                94
# genre            ['Drama']
# month               August
# country                USA
# origin                  UK
# director       Danny Boyle
# Name: 154, dtype: object
# tconst              tt0091251
# title            Come and See
# year                     1985
# cert                Not Rated
# rating                    8.3
# num_votes               25077
# run_time                  140
# genre        ['Drama', 'War']
# month                 October
# country               Hungary
# origin           Soviet Union
# director          Elem Klimov
# Name: 164, dtype: object
# tconst           tt0079470
# title        Life of Brian
# year                  1979
# cert                     R
# rating                 8.1
# num_votes           270754
# run_time                94
# genre           ['Comedy']
# month               August
# country                USA
# origin                  UK
# director       Terry Jones
# Name: 172, dtype: object
# tconst                              tt1979320
# title                                    Rush
# year                                     2013
# cert                                        R
# rating                                    8.1
# num_votes                              310102
# run_time                                  123
# genre        ['Action', 'Biography', 'Drama']
# month                               September
# country                                   USA
# origin                                     UK
# director                           Ron Howard
# Name: 174, dtype: object
# tconst                         tt0395169
# title                       Hotel Rwanda
# year                                2004
# cert                                   R
# rating                               8.1
# num_votes                         263186
# run_time                             121
# genre        ['Drama', 'History', 'War']
# month                           February
# country                              USA
# origin                                UK
# director                    Terry George
# Name: 176, dtype: object
# tconst              tt0091763
# title                 Platoon
# year                     1986
# cert                        R
# rating                    8.1
# num_votes              289977
# run_time                  120
# genre        ['Drama', 'War']
# month                February
# country                   USA
# origin                     UK
# director         Oliver Stone
# Name: 177, dtype: object
# tconst                                tt0046268
# title                         The Wages of Fear
# year                                       1953
# cert                                  Not Rated
# rating                                      8.2
# num_votes                                 35186
# run_time                                    131
# genre        ['Adventure', 'Drama', 'Thriller']
# month                                  February
# country                                     USA
# origin                                   France
# director                  Henri-Georges Clouzot
# Name: 181, dtype: object
# tconst                               tt1392190
# title                       Mad Max: Fury Road
# year                                      2015
# cert                                         R
# rating                                     8.1
# num_votes                               543733
# run_time                                   120
# genre        ['Action', 'Adventure', 'Sci-Fi']
# month                                      May
# country                                    USA
# origin                               Australia
# director                         George Miller
# Name: 183, dtype: object
# tconst                tt0053198
# title             The 400 Blows
# year                       1959
# cert                  Not Rated
# rating                      8.1
# num_votes                 69789
# run_time                     99
# genre        ['Crime', 'Drama']
# month                  November
# country                     USA
# origin                   France
# director      François Truffaut
# Name: 186, dtype: object
# tconst                               tt0107207
# title                In the Name of the Father
# year                                      1993
# cert                                         R
# rating                                     8.1
# num_votes                               108889
# run_time                                   133
# genre        ['Biography', 'Drama', 'History']
# month                                 February
# country                                    USA
# origin                                 Ireland
# director                          Jim Sheridan
# Name: 188, dtype: object
# tconst                   tt0060827
# title                      Persona
# year                          1966
# cert                     Not Rated
# rating                         8.1
# num_votes                    61150
# run_time                        83
# genre        ['Drama', 'Thriller']
# month                        March
# country                        USA
# origin                      Sweden
# director            Ingmar Bergman
# Name: 190, dtype: object
# tconst                   tt0245712
# title                Amores Perros
# year                          2000
# cert                             R
# rating                         8.1
# num_votes                   172736
# run_time                       154
# genre        ['Drama', 'Thriller']
# month                        April
# country                        USA
# origin                      Mexico
# director     Alejandro G. Iñárritu
# Name: 192, dtype: object
# tconst                               tt0052618
# title                                  Ben-Hur
# year                                      1959
# cert                                         G
# rating                                     8.1
# num_votes                               159162
# run_time                                   212
# genre        ['Adventure', 'Drama', 'History']
# month                                 December
# country                                     UK
# origin                                     USA
# director                         William Wyler
# Name: 196, dtype: object
# tconst                             tt0052311
# title                          Touch of Evil
# year                                    1958
# cert                                   PG-13
# rating                                   8.1
# num_votes                              72519
# run_time                                  95
# genre        ['Crime', 'Drama', 'Film-Noir']
# month                                    May
# country                                   UK
# origin                                   USA
# director                        Orson Welles
# Name: 197, dtype: object
# tconst                 tt1028532
# title        Hachi: A Dog's Tale
# year                        2009
# cert                           G
# rating                       8.1
# num_votes                 153467
# run_time                      93
# genre        ['Drama', 'Family']
# month                      March
# country                       UK
# origin                       USA
# director         Lasse Hallström
# Name: 198, dtype: object
# tconst                            tt0079944
# title                               Stalker
# year                                   1979
# cert                              Not Rated
# rating                                  8.1
# num_votes                             67926
# run_time                                163
# genre        ['Drama', 'Mystery', 'Sci-Fi']
# month                                 April
# country                         Netherlands
# origin                         Soviet Union
# director                   Andrei Tarkovsky
# Name: 204, dtype: object
# tconst                               tt0083987
# title                                   Gandhi
# year                                      1982
# cert                                        PG
# rating                                     8.1
# num_votes                               170733
# run_time                                   191
# genre        ['Biography', 'Drama', 'History']
# month                                 February
# country                                    USA
# origin                                      UK
# director                  Richard Attenborough
# Name: 206, dtype: object
# tconst                            tt0046911
# title                            Diabolique
# year                                   1955
# cert                              Not Rated
# rating                                  8.1
# num_votes                             41786
# run_time                                116
# genre        ['Drama', 'Horror', 'Mystery']
# month                              November
# country                                 USA
# origin                               France
# director              Henri-Georges Clouzot
# Name: 209, dtype: object
# tconst                  tt0056801
# title                          8½
# year                         1963
# cert                    Not Rated
# rating                        8.1
# num_votes                   78124
# run_time                      138
# genre        ['Drama', 'Fantasy']
# month                        June
# country                       USA
# origin                      Italy
# director         Federico Fellini
# Name: 214, dtype: object
# tconst                  tt0088247
# title              The Terminator
# year                         1984
# cert                            R
# rating                        8.1
# num_votes                  596549
# run_time                      107
# genre        ['Action', 'Sci-Fi']
# month                     October
# country                       USA
# origin                         UK
# director            James Cameron
# Name: 218, dtype: object
# tconst                         tt0036868
# title        The Best Years of Our Lives
# year                                1946
# cert                           Not Rated
# rating                               8.1
# num_votes                          40148
# run_time                             172
# genre        ['Drama', 'Romance', 'War']
# month                               June
# country                        Argentina
# origin                               USA
# director                   William Wyler
# Name: 220, dtype: object
# tconst                      tt0041546
# title        Kind Hearts and Coronets
# year                             1949
# cert                        Not Rated
# rating                            8.2
# num_votes                       26009
# run_time                          106
# genre             ['Comedy', 'Crime']
# month                            June
# country                           USA
# origin                             UK
# director                 Robert Hamer
# Name: 225, dtype: object
# tconst                tt0113247
# title                  La Haine
# year                       1995
# cert                  Not Rated
# rating                      8.1
# num_votes                102802
# run_time                     98
# genre        ['Crime', 'Drama']
# month                  February
# country                     USA
# origin                   France
# director      Mathieu Kassovitz
# Name: 227, dtype: object
# tconst                               tt0072684
# title                             Barry Lyndon
# year                                      1975
# cert                                        PG
# rating                                     8.1
# num_votes                               100821
# run_time                                   184
# genre        ['Adventure', 'Drama', 'History']
# month                                 December
# country                                    USA
# origin                                      UK
# director                       Stanley Kubrick
# Name: 229, dtype: object
# tconst                   tt0058946
# title        The Battle of Algiers
# year                          1966
# cert                     Not Rated
# rating                         8.1
# num_votes                    36961
# run_time                       121
# genre             ['Drama', 'War']
# month                    September
# country                        USA
# origin                       Italy
# director          Gillo Pontecorvo
# Name: 230, dtype: object
# tconst                              tt1220719
# title                                  Ip Man
# year                                     2008
# cert                                        R
# rating                                    8.1
# num_votes                              166650
# run_time                                  106
# genre        ['Action', 'Biography', 'Drama']
# month                                December
# country                                 China
# origin                              Hong Kong
# director                           Wilson Yip
# Name: 234, dtype: object
# tconst                                tt2084970
# title                        The Imitation Game
# year                                       2014
# cert                                      PG-13
# rating                                      8.1
# num_votes                                461017
# run_time                                    114
# genre        ['Biography', 'Drama', 'Thriller']
# month                                  December
# country                                     USA
# origin                                       UK
# director                          Morten Tyldum
# Name: 235, dtype: object
# tconst                            tt0058461
# title                  A Fistful of Dollars
# year                                   1964
# cert                                      R
# rating                                    8
# num_votes                            146301
# run_time                                 99
# genre        ['Action', 'Drama', 'Western']
# month                               January
# country                                 USA
# origin                                Italy
# director                       Sergio Leone
# Name: 241, dtype: object
# tconst                               tt1504320
# title                        The King's Speech
# year                                      2010
# cert                                         R
# rating                                       8
# num_votes                               500462
# run_time                                   118
# genre        ['Biography', 'Drama', 'History']
# month                                 December
# country                                    USA
# origin                                      UK
# director                            Tom Hooper
# Name: 243, dtype: object
# tconst             tt0050613
# title        Throne of Blood
# year                    1957
# cert               Not Rated
# rating                   8.1
# num_votes              31520
# run_time                 110
# genre              ['Drama']
# month               November
# country                  USA
# origin                 Japan
# director      Akira Kurosawa
# Name: 245, dtype: object
# tconst                          tt1954470
# title                  Gangs of Wasseypur
# year                                 2012
# cert                                    R
# rating                                8.3
# num_votes                           44775
# run_time                              320
# genre        ['Action', 'Crime', 'Drama']
# month                              August
# country                         Singapore
# origin                              India
# director                   Anurag Kashyap
# Name: 247, dtype: object
# tconst                  tt0118694
# title        In the Mood for Love
# year                         2000
# cert                           PG
# rating                        8.1
# num_votes                   75235
# run_time                       98
# genre        ['Drama', 'Romance']
# month                       March
# country                       USA
# origin                  Hong Kong
# director             Kar-Wai Wong
# Name: 249, dtype: object

# %% [markdown]
# Yup, looks like we want 'origin' instead of 'country'!  Let's get rid of 'country'.

# %%
del top['country']

# %%
top['origin'].value_counts()
# Out:
# USA             163
# UK               21
# Japan            14
# Italy            11
# France            8
# Germany           4
# Sweden            4
# Hong Kong         3
# Argentina         2
# Australia         2
# Iran              2
# India             2
# Soviet Union      2
# South Korea       2
# Ireland           2
# Spain             1
# Denmark           1
# Lebanon           1
# Mexico            1
# West Germany      1
# New Zealand       1
# Canada            1
# Brazil            1
# Name: origin, dtype: int64

# %% [markdown]
# Get director name (only take first if more than one):

# %%
# director = []
# for i in range(len(soup)):
#     dirs = []
#     for j in soup[i].find_all('span', itemprop = 'director'):
#         for k in j.find_all('span', itemprop = 'name'):
#             dirs.append(k.text.encode('utf8'))
# # these two lines will print all directors' names for movies with more than one director listed
# #            if len(dirs) != 1:
# #                print dirs
#     if len(dirs) > 1:
#         mini_list = []
#         mini_list.append(dirs[0])
#         director.append(mini_list)
#     else:
#         director.append(dirs)
        
# len(director)
# Out:
# 250

# %%
# director = pd.DataFrame(director)
# director.to_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/director.csv', index = False)

# %%
director = pd.read_csv('/Users/Rebecca/DSI-projects/projects/project-06/assets/director.csv')
top['director'] = director

# %% [markdown]
# Who directed the Italian movies?

# %%
top[top['origin'] == 'Italy'][['title', 'year', 'director']].sort('year', ascending = False)
# Out:
# /Users/Rebecca/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning:
#
# sort(columns=....) is deprecated, use sort_values(by=.....)
#                               title  year            director
# 25                Life Is Beautiful  1997     Roberto Benigni
# 55                  Cinema Paradiso  1988  Giuseppe Tornatore
# 67      Once Upon a Time in America  1984        Sergio Leone
# 27     Once Upon a Time in the West  1968        Sergio Leone
# 8    The Good, the Bad and the Ugly  1966        Sergio Leone
# 230           The Battle of Algiers  1966    Gillo Pontecorvo
# 97           For a Few Dollars More  1965        Sergio Leone
# 241            A Fistful of Dollars  1964        Sergio Leone
# 214                              8½  1963    Federico Fellini
# 173               Nights of Cabiria  1957    Federico Fellini
# 89                  Bicycle Thieves  1948    Vittorio De Sica

# %% [markdown]
# Surprise!  There are no female directors with more than two movies in the Top 250 list:

# %%
dir_count = pd.DataFrame(top['director'].value_counts())
dir_count.columns = ['count']
dir_count[dir_count['count'] > 2]
# Out:
#                       count
# Stanley Kubrick           7
# Steven Spielberg          7
# Alfred Hitchcock          7
# Christopher Nolan         7
# Martin Scorsese           7
# Akira Kurosawa            6
# Hayao Miyazaki            6
# Sergio Leone              5
# Charles Chaplin           5
# Billy Wilder              5
# Quentin Tarantino         5
# Ridley Scott              4
# Ingmar Bergman            4
# Sidney Lumet              3
# Pete Docter               3
# William Wyler             3
# Frank Capra               3
# David Fincher             3
# Clint Eastwood            3
# James Cameron             3
# Francis Ford Coppola      3
# Peter Jackson             3

# %%
top.head()
# Out:
#       tconst                     title  year   cert  rating  num_votes  \
# 0  tt0111161  The Shawshank Redemption  1994      R     9.3    1679754
# 1  tt0068646             The Godfather  1972      R     9.2    1149267
# 2  tt0071562    The Godfather: Part II  1974      R     9.0     785960
# 3  tt0468569           The Dark Knight  2008  PG-13     9.0    1664826
# 4  tt0108052          Schindler's List  1993      R     8.9     859708
#
#    run_time                              genre     month origin  \
# 0       142                 ['Crime', 'Drama']   October    USA
# 1       175                 ['Crime', 'Drama']     March    USA
# 2       202                 ['Crime', 'Drama']  December    USA
# 3       152   ['Action', 'Adventure', 'Crime']      July    USA
# 4       195  ['Biography', 'Drama', 'History']  February    USA
#
#                director
# 0        Frank Darabont
# 1  Francis Ford Coppola
# 2  Francis Ford Coppola
# 3     Christopher Nolan
# 4      Steven Spielberg

# %%
money = []
for i in range(len(soup)):
    lil_money = []
    for j in soup[i].find_all('div', class_ = 'txt-block'):
            lil_money.append(j.text.encode('utf8'))
    money.append(lil_money)

len(money)
# Out:
# 250

# %%
money
# Out:
# [['\nTaglines:\nFear can hold you prisoner. Hope can set you free.        ',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated R for language and prison violence\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 14 October 1994 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Rita Hayworth and the Shawshank Redemption\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nSt. Croix, U.S. Virgin Islands\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $25,000,000        \n\n      (estimated)\n',
#   '\nGross:        $28,341,469        \n\n      (USA)\n',
#   '\nProduction Co:\n\nCastle Rock Entertainment \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n142 min\n',
#   '\nSound Mix:\nDolby Digital\n',
#   '\nColor:\nColor\n(Technicolor)    ',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   '\nTrivia\nIn French, Dufresne means "ash" or "ash tree." The ash tree in folklore and symbolism is typically representative of healing, while also a sign of death and rebirth, all of which apply to Andy, his sentence, and his eventual escape from Shawshank.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nWhen Red is on the bus, one shot shows all of the windows on the bus open. In fact, Red's arm is hanging outside the window. In the very next shot of the bus (a long shot from a distance), all of the windows are closed.        See more  \xc2\xbb\n    ",
#   '\nCrazy Credits\nThe man who cried and was beaten when Andy first arrived is listed and credited as "Fat Ass" -- the other inmates\' nickname for him.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nThe Godfather is now a movie.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nCertificate:\nR\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n|\nOfficial site\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n|\nItalian\n|\nLatin\n',
#   '\nRelease Date: 24 March 1972 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   "\nAlso Known As: Mario Puzo's The Godfather\n      \nSee more\xc2\xa0\xc2\xbb\n      \n",
#   '\nFilming Locations:\nNY Eye and Ear Infirmary, 2nd Avenue & East 13th Street, New York City, New York, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $6,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         $223,758        \n\n      (USA)\n      (4 April 1997)\n',
#   '\nGross:        $134,821,952        \n\n      (USA)\n(2 May 1997)\n',
#   '\nProduction Co:\n\nParamount Pictures,        \nAlfran Productions \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n175 min\n',
#   '\nSound Mix:\nDTS\n(re-release)| Mono\n',
#   '\nColor:\nColor\n(Technicolor)    ',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   '\nTrivia\nThere was intense friction between Francis Ford Coppola and Paramount, in which [Paramount] frequently tried to have Coppola replaced, citing his inability to stay on schedule, unnecessary expenses, and production and casting errors (Coppola actually completed the film ahead of schedule and budget).        See more  \xc2\xbb\n    ',
#   '\nGoofs\nWhen Michael is telling Kay about Luca Brasi, she has a cigarette in her left hand which disappears and reappears between shots. A few seconds later, the cigarette is gone and Kay has a fork in her left hand which then jumps to her right hand.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nIn the end credits, Marlon Brando\'s name is the only one that is not accompanied by the character name that he plays (e.g. "as Vito Corleone").         See more  \xc2\xbb\n    '],
#  ['\nCertificate:\nR\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n|\nOfficial site\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n|\nItalian\n|\nSpanish\n|\nLatin\n|\nSicilian\n',
#   '\nRelease Date: 20 December 1974 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   "\nAlso Known As: Mario Puzo's The Godfather: Part II\n      \nSee more\xc2\xa0\xc2\xbb\n      \n",
#   '\nFilming Locations:\n2045 N. Hibiscus Drive, North Miami, Florida, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $13,000,000        \n\n      (estimated)\n',
#   '\nGross:        $57,300,000        \n\n      (USA)\n',
#   '\nProduction Co:\n\nParamount Pictures,        \nThe Coppola Company \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n202 min\n|\n220 min\n            (The Godfather Trilogy 1901-1980 VHS Special Edition)\n    ',
#   '\nSound Mix:\nMono\n',
#   '\nColor:\nColor\n(Technicolor)    ',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   '\nTrivia\nVito\'s birthday is December 7. Sonny curses at the "Japs" for dropping bombs in Hawaii on his father\'s birthday.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nIn the establishing shot of the Hotel Washington, where Kay tells Michael she wants to leave him, a modern 70's car can be seen crossing the intersection in the background.        See more  \xc2\xbb\n    ",
#   '\nCrazy Credits\nAs with the first film no opening credits are shown. Although it is now commonplace for films not to have opening credits, it was considered innovative in 1974.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nWhy So Serious?                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG-13 for intense sequences of violence and some menace\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nCitizens for Batman\n|\nCity of Gotham Police Department\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nUSA\n|\nUK\n',
#   '\nLanguage:\nEnglish\n|\nMandarin\n',
#   '\nRelease Date: 18 July 2008 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Batman Begins 2\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nTimes Square, Causeway Bay, Hong Kong\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $185,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         $158,411,483        \n\n      (USA)\n      (18 July 2008)\n',
#   '\nGross:        $533,316,061        \n\n      (USA)\n(27 February 2009)\n',
#   '\nProduction Co:\n\nWarner Bros.,        \nLegendary Pictures,        \nSyncopy \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n152 min\n',
#   '\nSound Mix:\nDolby Digital\n| SDDS\n| DTS\n',
#   '\nColor:\nColor\n(Technicolor)    ',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   "\nTrivia\nThe serrated edges on the side of the Batman's gauntlets were inspired by the pulp character Tony Quinn, the Black Bat, whose origin (he was a district attorney victim of an acid flinging gangster) was borrowed for Two-Face.        See more  \xc2\xbb\n    ",
#   '\nGoofs\nWhen Lucius Fox meets with Lau on the terrace of his Hong Kong office building, you can clearly see all of the McCormick Place buildings of Chicago in the background behind Fox.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nThe DC logo contains two comic-book images: a shot of the Riddler, and picture of Batman punching him out.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nThe List Is Life.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated R for language, some sexuality and actuality violence\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n|\nOfficial site\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n|\nHebrew\n|\nGerman\n|\nPolish\n',
#   '\nRelease Date: 4 February 1994 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: La lista de Schindler\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nJ\xc3\xb3zefa, Krak\xc3\xb3w, Malopolskie, Poland\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $22,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         \xc2\xa31,234,591        \n\n      (UK)\n      (4 March 1994)\n',
#   '\nGross:        $96,067,179        \n\n      (USA)\n',
#   '\nProduction Co:\n\nUniversal Pictures,        \nAmblin Entertainment \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n195 min\n|\n185 min\n            (TV)\n    ',
#   '\nSound Mix:\nDTS\n| DTS-Stereo\n',
#   '\nColor:\n Black and White\n| Color\n',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   '\nTrivia\nThe film was banned in several Muslim-majority nations, including Malaysia, Indonesia, Lebanon and Egypt. The general excuse for the bans was that the film was unfair towards Germans (meaning Nazis) and overly sympathetic to Jews. Neo-Nazis in Western countries, including the U.S. and Canada, campaigned for the film to be banned there but were entirely ignored.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nThe Golden Party Badge (Goldenes Parteiabzeichen) that Schindler is holding is the 'large' military version and not the civilian type that he would have had, if he had been awarded one.        See more  \xc2\xbb\n    ",
#   '\nCrazy Credits\nPolish fonts were used in the credits sequence        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\n...it explodes like twelve sticks of dynamite!                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nCertificate:\nNot Rated\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nMGM Studios [United States]\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: April 1957 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Twelve Angry Men\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nNew York County Courthouse - 60 Centre Street, New York City, New York, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $350,000        \n\n      (estimated)\n',
#   '\nProduction Co:\n\nOrion-Nova Productions \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n96 min\n',
#   '\nSound Mix:\nMono\n',
#   '\nColor:\n Black and White\n',
#   '\nAspect Ratio: 1.66 : 1\n    ',
#   '\nTrivia\nThe movies mentioned by Juror #4 in the double feature he saw are "The Scarlett Circle" and "The Amazing Mrs. Bainbridge" (wrongly named by him as "The Remarkable Mrs. Bainbridge"). Neither of them exist.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nJuror #9 reveals that be had noticed that a key witness that testified seeing the murder from afar when awakened in bed, had marks on her nose typically left by eye glasses, raising reasonable doubt the truthfulness of her testimony. In his subsequent line of questioning with the be-speckled Juror #4, Juror #9 then mentions he has 20/20 vision. Yet, upon subsequent close-ups, Juror #9 clearly has the same marks on his nose that the witness and Juror #4 had, indicating that he also wears glasses, invalidating his earlier claim of 20/20 vision.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nAt the end of the film, the actors are billed in order of their juror numbers; thus Henry Fonda, although the star of the film, appears 8th.        See more  \xc2\xbb\n    '],
#  ["\nTaglines:\nYou won't know the facts until you've seen the fiction.                \n See more\xc2\xa0\xc2\xbb\n                \n",
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated R for strong graphic violence and drug use, pervasive strong language and some sexuality\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n|\nOfficial site\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n|\nSpanish\n|\nFrench\n',
#   '\nRelease Date: 14 October 1994 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Black Mask\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\n1435 Flower Street, Glendale, California, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $8,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         \xc2\xa34,243,233        \n\n      (UK)\n      (11 November 1994)\n',
#   '\nGross:        $107,930,000        \n\n      (USA)\n',
#   '\nProduction Co:\n\nMiramax,        \nA Band Apart,        \nJersey Films \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n154 min\n|\n178 min\n            (original cut)\n    ',
#   '\nSound Mix:\nDolby Digital\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   '\nTrivia\nIncluded among the "1001 Movies You Must See Before You Die", edited by Steven Schneider.        See more  \xc2\xbb\n    ',
#   "\nGoofs\n(at around 41 mins) When Vincent and Mia are in Jack Rabbit's, the video wall behind them showing a street scene jumps (e.g., cars and people disappear) each time the shot switches from Vincent to Mia.        See more  \xc2\xbb\n    ",
#   "\nCrazy Credits\nThe opening credits end with Produced by Lawrence Bender. Usually movies end opening credits with the Director's credit, however Written and Directed by Quentin Tarantino starts the end credits.        See more  \xc2\xbb\n    "],
#  ['\nTaglines:\nThere can be no triumph without loss. No victory without suffering. No freedom without sacrifice.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG-13 for intense epic battle sequences and frightening images\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n|\nOfficial site: The Lord of the Rings Trilogy\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nUSA\n|\nNew Zealand\n',
#   '\nLanguage:\nEnglish\n|\nQuenya\n|\nOld English\n|\nSindarin\n',
#   '\nRelease Date: 17 December 2003 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: The Return of the King\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nDry Creek Quarry, Wellington, New Zealand\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $94,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         \xc2\xa315,021,761        \n\n      (UK)\n      (19 December 2003)\n',
#   '\nGross:        $377,019,252        \n\n      (USA)\n(28 May 2004)\n',
#   '\nProduction Co:\n\nNew Line Cinema,        \nWingNut Films,        \nThe Saul Zaentz Company \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n201 min\n|\n263 min\n            (Blu-Ray Extended Edition)\n          |\n254 min\n            (Special DVD Extended Edition)\n          |\n182 min\n            (DVD Widescreen Edition)\n    ',
#   '\nSound Mix:\nDTS-ES\n| Dolby Digital EX\n| SDDS\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   '\nTrivia\nA normal major motion picture averages about 200 effects shots. This film had 1488.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nWhen Eowyn is fighting the Witch King, the strap holding her helmet is buckled, however, when she pulls off her helmet, there is no strap on it at all.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nAt the end of the credits, a very long list of names from the Lord of the Rings Fan Club whom the authors want to thank to is displayed. The name of Elijah Wood is in that list.        See more  \xc2\xbb\n    '],
#  ["\nTaglines:\nFor Three Men The Civil War Wasn't Hell.  It Was Practice!                \n See more\xc2\xa0\xc2\xbb\n                \n",
#   '\nCertificate:\nNot Rated\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nCountry:\nItaly\n|\nSpain\n|\nWest Germany\n|\nUSA\n',
#   '\nLanguage:\nItalian\n',
#   '\nRelease Date: 29 December 1967 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: The Good, the Bad and the Ugly\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nMini Hollywood, Tabernas, Almer\xc3\xada, Andaluc\xc3\xada, Spain\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $1,200,000        \n\n      (estimated)\n',
#   '\nGross:        $6,100,000        \n\n      (USA)\n',
#   '\nProduction Co:\n\nProduzioni Europee Associati (PEA),        \nArturo Gonz\xc3\xa1lez Producciones Cinematogr\xc3\xa1ficas, S.A,        \nConstantin Film Produktion \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n161 min\n|\n186 min\n            (dubbed)\n          |\n179 min\n            (2003 extended English)\n          |\n142 min\n            (1968)\n            (cut)\n    ',
#   '\nSound Mix:\nMono\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   '\nTrivia\nEli Wallach and Clint Eastwood flew to Madrid together and between shooting scenes, Eastwood would relax and practice his golf swing.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nWhen the two armies battle at the bridge, the Confederates are using the flag with the blue criss-cross on the red field. This is not the Confederate national flag, rather it is the banner of Gen. Robert E. Lee's Army of Northern Virginia. It would have been in battles in the east, not in the west.        See more  \xc2\xbb\n    "],
#  ['\nTaglines:\nMischief. Mayhem. Soap.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated R for disturbing and graphic depiction of violent anti-social behavior, sexuality and language\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n\n\n',
#   '\nCountry:\nUSA\n|\nGermany\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 15 October 1999 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: El club de la pelea\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\n421 W. Eighth Street, Los Angeles, California, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $63,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         $11,035,485        \n\n      (USA)\n      (15 October 1999)\n',
#   '\nGross:        $37,023,395        \n\n      (USA)\n(25 February 2000)\n',
#   '\nProduction Co:\n\nFox 2000 Pictures,        \nRegency Enterprises,        \nLinson Films \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n139 min\n|\n151 min\n            (workprint)\n    ',
#   '\nSound Mix:\nDolby Digital\n| DTS\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   "\nTrivia\nDuring the shooting of the night exteriors of Tyler's house in San Pedro, the helium balloon lights which were floated above the house by director of photography Jeff Cronenweth prompted a number of UFO sightings, resulting in the Lomita Sheriff's Department visiting the set to inquire what was going on.        See more  \xc2\xbb\n    ",
#   '\nGoofs\nWhen The Mechanic (Holt McCallany) sprays the Seminary Student (Matt Winston) with a hose, the camera briefly shakes because the cameraman was laughing uncontrollably.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nJust as the closing credits are about to start, a flash-frame-shot of a penis appears on the screen.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nOne Ring To Rule Them All.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG-13 for epic battle sequences and some scary images\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nAllocine (French)\n|\nAurum [Spain]\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nNew Zealand\n|\nUSA\n',
#   '\nLanguage:\nEnglish\n|\nSindarin\n',
#   '\nRelease Date: 19 December 2001 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: The Fellowship of the Ring\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nFort Dorset, Miramar, Wellington, New Zealand\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $93,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         \xc2\xa311,058,045        \n\n      (UK)\n      (21 December 2001)\n',
#   '\nGross:        $313,837,577        \n\n      (USA)\n(5 December 2003)\n',
#   '\nProduction Co:\n\nNew Line Cinema,        \nWingNut Films,        \nThe Saul Zaentz Company \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n178 min\n|\n208 min\n            (Special DVD Extended Edition)\n          |\n228 min\n            (Blu Ray Extended Edition)\n          |\n162 min\n            (DVD Widescreen Edition)\n    ',
#   '\nSound Mix:\nDTS-ES\n| Dolby Digital EX\n| SDDS\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   "\nTrivia\nThe Tolkien estate was never in favor of Peter Jackson's film adaptation but seeing as J.R.R. Tolkien signed the rights away in 1968 for $15,000 ($99,233.19 in 2012 dollars), there was nothing they could do about it. Tolkien's grandson Simon Tolkien came out in support of the production and was, according to some accounts, disowned by his relatives, although Simon's father Christopher Tolkien later denied this.        See more  \xc2\xbb\n    ",
#   "\nGoofs\nSam's clothes are completely dry, moments after Frodo saved him from drowning.        See more  \xc2\xbb\n    ",
#   '\nCrazy Credits\nAfter the end credits, the DVD and Blu Ray editions of the extended cut feature a list of "Lord of the Rings fan-club members" who contributed financially to the project in exchange for a credit. This additional credit sequence lasts 20 minutes.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nThe Star Wars saga continues                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG for sci-fi action violence\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n|\nOfficial site\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 20 June 1980 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Star Wars V: The Empire Strikes Back\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nBanks, Oregon, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $18,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         ITL\xc2\xa0609,584,000        \n\n      (Italy)\n      (11 April 1997)\n',
#   '\nGross:        $290,158,751        \n\n      (USA)\n(9 May 1997)\n',
#   '\nProduction Co:\n\nLucasfilm \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n124 min\n|\n127 min\n            (special edition)\n    ',
#   '\nSound Mix:\n70 mm 6-Track\n(70 mm prints)| Dolby Stereo\n(35 mm prints)    ',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   '\nTrivia\nDirector Irvin Kershner provided the voice of Darth Vader himself in the temporary mix of the film, before James Earl Jones recorded the final version.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nThe claw of the Wampa hits Luke on his neck which is all covered up. In the following shot he has bleeding wounds on his face.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nIn the section of the end credits cast list devoted to the Rebel Forces, there are no fewer than three misprints: Christopher Malcolm is credited as "Christopher Malcom"; Denis Lawson is "Dennis Lawson"; and the character Dack, whose spelling is attested in the script as well as in books and other media, in the credits is spelled "Dak".        See more  \xc2\xbb\n    '],
#  ["\nTaglines:\nLife is like a box of chocolates...you never know what you're gonna get.                \n See more\xc2\xa0\xc2\xbb\n                \n",
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG-13 for drug content, some sensuality and war violence\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 6 July 1994 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Forrest Gump: The IMAX Experience\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nMonument Valley, Arizona, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $55,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         \xc2\xa311,302,303        \n\n      (UK)\n      (11 November 1994)\n',
#   '\nGross:        $329,691,196        \n\n      (USA)\n',
#   '\nProduction Co:\n\nParamount Pictures \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n142 min\n',
#   '\nSound Mix:\nDTS\n| Dolby Digital\n',
#   '\nColor:\n Black and White\n| Color\n',
#   '\nAspect Ratio: 2.36 : 1\n    ',
#   '\nTrivia\nSally Field starred in Beyond the Poseidon Adventure (1979) as a salvager on a boat named Jenny.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nWhen Forrest and Jenny watch the fireworks, the sound from the fireworks bursting comes exactly on the same time as they appear. There should be a delay as the sound travels over some distance.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nThe dream is real.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG-13 for sequences of violence and action throughout\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n|\nWarner Bros. [Germany]\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nUSA\n|\nUK\n',
#   '\nLanguage:\nEnglish\n|\nJapanese\n|\nFrench\n',
#   '\nRelease Date: 16 July 2010 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Inception: The IMAX Experience\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nBedfordshire, England, UK\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $160,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         \xc2\xa35,912,814        \n\n      (UK)\n      (16 July 2010)\n',
#   '\nGross:        $292,568,851        \n\n      (USA)\n(31 December 2010)\n',
#   '\nProduction Co:\n\nWarner Bros.,        \nLegendary Pictures,        \nSyncopy \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n148 min\n',
#   '\nSound Mix:\nDolby Digital\n| DTS\n| SDDS\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   "\nTrivia\nThe character Cobb is an architect in this movie. The actor Alex Haw, who played another character also named Cobb in Christopher Nolan 's earlier movie Following (1998), is actually an architect in real life.        See more  \xc2\xbb\n    ",
#   "\nGoofs\nWhen Arthur is tying up the team in the hotel scene, Eames' arms are tightly bound to his sides. When Arthur is pushing them down the corridors, Eames' arms float freely. Then, in the shot looking down into the elevator, his arms are once again bound tightly.        See more  \xc2\xbb\n    ",
#   '\nCrazy Credits\nThere are no opening credits or titles.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nThe Journey Continues December 18th                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG-13 for epic battle sequences and scary images\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nAurum [Spain]\n|\nNew Line Cinema\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nUSA\n|\nNew Zealand\n',
#   '\nLanguage:\nEnglish\n|\nSindarin\n|\nOld English\n',
#   '\nRelease Date: 18 December 2002 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: The Two Towers\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nMount Sunday, Canterbury, South Island, New Zealand\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $94,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         \xc2\xa313,063,560        \n\n      (UK)\n      (20 December 2002)\n',
#   '\nGross:        $340,478,898        \n\n      (USA)\n(12 December 2003)\n',
#   '\nProduction Co:\n\nNew Line Cinema,        \nWingNut Films,        \nThe Saul Zaentz Company \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n179 min\n|\n235 min\n            (Blu Ray Extended Edition)\n          |\n223 min\n            (Special DVD Extended Edition)\n          |\n171 min\n            (DVD Widescreen Edition)\n    ',
#   '\nSound Mix:\nDTS-ES\n| Dolby Digital EX\n| SDDS\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   "\nTrivia\nEASTER EGG: In the extended DVD version on the first movie disc, go to chapter 29-30 under the scene selection. Press down under chapter 30 and a gold ring will appear. It's a hidden extra of the MTV awards for Andy Serkis receiving best virtual performance.        See more  \xc2\xbb\n    ",
#   '\nGoofs\nWhen the gate to Mordor is opened, it is clearly seen to be as thick as the wall, and each corner is seen to be a right angle. There is no space at all in between the gate and the wall when it is closed, later on in the same scene. However, the gate opens on a curve, and so would get stuck every time it opened or closed, unless the wall was somehow retracted. We do not see the wall retracted at all, thus it is physically impossible for such a gate to exist.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nJust like the previous "Lord of the Rings" movie, there are no opening credits after the title has been shown.        See more  \xc2\xbb\n    '],
#  ["\nTaglines:\nIf he's crazy, what does that make you?        ",
#   '\nCertificate:\nR\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 21 November 1975 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Atrapado sin salida\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nDepoe Bay, Oregon, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $4,400,000        \n\n      (estimated)\n',
#   '\nGross:        $112,000,000        \n\n      (USA)\n',
#   '\nProduction Co:\n\nFantasy Films \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n133 min\n',
#   '\nSound Mix:\nMono\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   '\nTrivia\nMel Lambert, who played the harbor master, was a local businessman rather than an actor; he had a strong relationship with Native Americans throughout the area, and it was he who suggested Will Sampson for the role of Chief Bromden.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nNear the end of the party Rose's microphone pack is visible on her back while she is dancing.        See more  \xc2\xbb\n    ",
#   '\nCrazy Credits\nThe cast is credited in alphabetical order in the end credits, except for Brad Dourif, who is listed last as follows: "and introducing / Brad Dourif as Billy Bibbit".        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nThree Decades of Life in the Mafia.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nCertificate:\nR\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n|\nItalian\n',
#   '\nRelease Date: 21 September 1990 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Good Fellas\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\n19 Alfred Lane, New Rochelle, New York, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $25,000,000        \n\n      (estimated)\n',
#   '\nGross:        $46,836,394        \n\n      (USA)\n',
#   '\nProduction Co:\n\nWarner Bros. \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n146 min\n',
#   '\nSound Mix:\nDolby SR\n',
#   '\nColor:\nColor\n(Technicolor)    ',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   "\nTrivia\nThe phone number for Morrie's wig shop is 555-HAIR (555-4247).        See more  \xc2\xbb\n    ",
#   "\nGoofs\nWhen we first see Paulie's house, a cable TV wire is clearly visible on the outside. Cable TV didn't come to New York's outer boroughs until the mid-1980s.        See more  \xc2\xbb\n    "],
#  ['\nTaglines:\nThe World\'s population thinks it\'s real. On March 31st, they will see the "Real World".                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated R for sci-fi violence and brief language\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 31 March 1999 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Matrix\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nAON Tower, Kent Street, Sydney, New South Wales, Australia\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $63,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         $27,788,331        \n\n      (USA)\n      (2 April 1999)\n',
#   '\nGross:        $171,383,253        \n\n      (USA)\n(17 September 1999)\n',
#   '\nProduction Co:\n\nWarner Bros.,        \nVillage Roadshow Pictures,        \nGroucho II Film Partnership \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n136 min\n',
#   '\nSound Mix:\nDTS\n| Dolby Digital\n| SDDS\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   "\nTrivia\nCarrie-Anne Moss twisted her ankle while shooting one of her scenes but decided not to tell anyone until after filming, so they wouldn't re-cast her.        See more  \xc2\xbb\n    ",
#   "\nGoofs\nIn the building the group returns to after seeing the Oracle, smoke appears around the hardline before it's cut by the agents (or by one of their minions). Also, the amount of smoke is considerably more than wires that size could produce unless they were already on fire.        See more  \xc2\xbb\n    ",
#   "\nCrazy Credits\nAt the end of all the credits, the URL for the (now defunct) website of the film is given, www.whatisthematrix.com, along with a password, 'steak'. There's a 'secret' link on the page that requests a password.        See more  \xc2\xbb\n    "],
#  ['\nTaglines:\nThe Mighty Warriors Who Became the Seven National Heroes of a Small Town                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nCertificate:\nUnrated\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nCountry:\nJapan\n',
#   '\nLanguage:\nJapanese\n',
#   '\nRelease Date: 19 November 1956 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Seven Samurai\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nJapan\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $2,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         $21,830        \n\n      (USA)\n      (30 August 2002)\n',
#   '\nGross:        $269,061        \n\n      (USA)\n(29 August 2003)\n',
#   '\nProduction Co:\n\nToho Company \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n207 min\n|\n160 min\n            (international)\n          |\n202 min\n            (2002 re-release)\n          |\n150 min\n            (original)\n          |\n190 min\n            (1991 re-release)\n          |\n158 min\n            (cut)\n            (original)\n          |\n203 min\n            (re-release)\n          |\n207 min\n            (restored)\n          |\n202 min\n            (DVD edition)\n    ',
#   '\nSound Mix:\nMono\n| Stereo\n(re-release prints)    ',
#   '\nColor:\n Black and White\n',
#   '\nAspect Ratio: 1.37 : 1\n    ',
#   '\nTrivia\nFilming had to be stopped several times due to a shortage of horses for the final battle sequences.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nDuring the first scene when the people in the village are discussing what to do with the bandits, it's visible that they are wearing bald-wigs.        See more  \xc2\xbb\n    "],
#  ['\nTaglines:\nThe original is back. (1982 Reissue)                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG for sci-fi violence and brief mild language\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n|\nOfficial site\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 25 May 1977 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: A New Hope\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nTikal National Park, Guatemala\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $11,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         $35,906,661        \n\n      (USA)\n      (31 January 1997)\n',
#   '\nGross:        $460,935,665        \n\n      (USA)\n(2 May 1997)\n',
#   '\nProduction Co:\n\nLucasfilm,        \nTwentieth Century Fox Film Corporation \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n121 min\n|\n125 min\n            (special edition)\n    ',
#   '\nSound Mix:\n70 mm 6-Track\n(70 mm prints)| Dolby\n(as Dolby System)\xc2\xa0(35 mm prints)\xc2\xa0(1977 print)| DTS-Stereo\n(as DTS Stereo\xc2\xae in selected theatres)\xc2\xa0(1997 print)| Dolby Digital\n(as Dolby\xc2\xae Digital in selected theatres)\xc2\xa0(1997 print)| SDDS\n(as Sony Dynamic Digital SoundTM in selected theatres)\xc2\xa0(1997 print)| Mono\n(some 35 mm prints)\xc2\xa0(other 16 mm prints)    ',
#   '\nColor:\nColor\n(Technicolor)    ',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   '\nTrivia\nIn an early version of the screenplay, Luke Skywalker was a 60-year old general and Han Solo had green skin and gills.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nDuring the Death Star battle, you hear: "Red 6, can you see Red 5?" and a voice seems to answer. This is after Tono Porkins, who was Red 6, has been destroyed. But there is a hectic space battle going on with tons of Rebel and Imperial ships - and as a result, tons of radio calls. The response was likely an irrelevant call that just happened to get picked up at an odd moment.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nThe film has no opening credits. Instead, the first credits seen at the end of the film are presented in the order in which they would have otherwise been shown at the start. Although by the late 1990s it was commonplace for films to not have opening credits, in 1977 it was somewhat unusual for a major film to not have opening credits.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nIf you run it will get you. If you stay it will eat you.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated R for strong brutal violence, sexuality, drug content and language\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nlighthouse pictures [Singapore] (English)\n|\nMars Distribution (French)\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nBrazil\n|\nFrance\n',
#   '\nLanguage:\nPortuguese\n',
#   '\nRelease Date: 13 February 2004 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: City of God\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nCidade de Deus, Rio de Janeiro, Rio de Janeiro, Brazil\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $3,300,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         $541,996        \n\n      (Brazil)\n      (30 August 2002)\n',
#   '\nGross:        $7,563,397        \n\n      (USA)\n(18 June 2004)\n',
#   '\nProduction Co:\n\nO2 Filmes,        \nVideoFilmes,        \nGlobo Filmes \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n130 min\n|\n135 min\n',
#   '\nSound Mix:\nDolby Digital\n| SDDS\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   '\nTrivia\nIncluded among the "1001 Movies You Must See Before You Die", edited by Steven Schneider.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nWhenever Tio Sam is in the apartment to sell Ze Pequeno the weapons, he inquires whether or not Ze has seen a mini Ruger, which is the same caliber of an M-16, inaccessible in Brazil. Ze shows no interest or knowledge of the Ruger, though he is shown holding up one just like it whenever Buscape is taking photos of the gang.        See more  \xc2\xbb\n    ',
#   "\nCrazy Credits\nThe closing credits shows pictures of the main actors,  their name, their character's name and pictures of the real life characters (for the ones based on existing people).        See more  \xc2\xbb\n    "],
#  ['\nTaglines:\nEarnest Hemingway once wrote, "The world is a fine place and worth fighting for." I believe the second part.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated R for grisly afterviews of horrific and bizarre killings, and for strong language\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 22 September 1995 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Seven\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nPacific Electric Building, Los Angeles, California, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $33,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         \xc2\xa311,434,343        \n\n      (UK)\n      (19 January 1996)\n',
#   '\nGross:        $100,125,340        \n\n      (USA)\n',
#   '\nProduction Co:\n\nCecchi Gori Pictures,        \nJuno Pix,        \nNew Line Cinema \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n127 min\n',
#   '\nSound Mix:\nDTS\n| Dolby Digital\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   '\nTrivia\nAccording to earlier versions of the script, the unspoken name of the police captain is Captain Lucas.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nMills gets out of a bed with only a quilted mattress cover. He puts on his shirt and tie and walks back to the bed which now has a sheet on it.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nThe opening credits are done over broken, blurred images of John Doe removing the skin from his fingertips and sewing it into his journals.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nDr. Hannibal Lecter. Brilliant. Cunning. Psychotic. In his mind lies the clue to a ruthless killer. - Clarice Starling, FBI. Brilliant. Vulnerable. Alone. She must trust him to stop the killer.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nCertificate:\nR\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n\n\n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 14 February 1991 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Silence of the Lambs\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nClay County, West Virginia, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $19,000,000        \n\n      (estimated)\n',
#   '\nGross:        $130,727,000        \n\n      (USA)\n',
#   '\nProduction Co:\n\nStrong Heart/Demme Production,        \nOrion Pictures \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n118 min\n|\n138 min\n            (original cut)\n    ',
#   '\nSound Mix:\nDolby SR\n',
#   '\nColor:\nColor\n(Eastmancolor)    ',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   '\nTrivia\nThe real life american astronaut Alan Shepard - the first american in space - was played by both Scott Glenn and Ted Levine. Glenn played Shepard in the 1983 movie The Right Stuff and Levine played him in the 1998 HBO mini-series From the Earth to the Moon.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nWhen Clarice visits the entomologists to identify the moth pupa, they say while examining the chrysalis that it must\'ve been specially raised from imported eggs and fed "honey and nightshade". Deaths Head moth larvae, like most caterpillars, eat only vegetation; the adult moths eat honey.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nThe ending scene continues throughout the entire credits        See more  \xc2\xbb\n    '],
# ...
#   '\nGoofs\nWhen Hawkeye is breaking onto the Helicarrier, he and some snipers break down a duct cover and enter. When the cover lands on the floor, it is resting away from some pipes with some slats missing. As soon as Hawkeye enters the duct, the cover is now resting against the pipes, and the slats have reappeared.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nSPOILER:  There is a scene part way through credits:  Marvel Character Thanos appears with The Other by his side. They are both looking down on Planet Earth with Thanos smiling, stating that they underestimated Earth.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nThis is the man with no name. Danger fits him like a glove.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated R for violence\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nCountry:\nItaly\n|\nSpain\n|\nWest Germany\n',
#   '\nLanguage:\nItalian\n|\nSpanish\n',
#   '\nRelease Date: 18 January 1967 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: A Fist Full of Dollars\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nAldea del Fresno, Madrid, Spain\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $200,000        \n\n      (estimated)\n',
#   '\nGross:        $3,500,000        \n\n      (USA)\n',
#   '\nProduction Co:\n\nJolly Film,        \nConstantin Film Produktion,        \nOcean Films \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n99 min\n',
#   '\nSound Mix:\nMono\n(Western Electric Sound System)    ',
#   '\nColor:\nColor\n(Technicolor)    ',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   '\nTrivia\nSince all footage was filmed silent, Clint Eastwood did not add his voice to the soundtrack until 1967, when the movie was prepared for U.S. release.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nAt the end, when Silvanito shoots Esteban Rojo, the sound of the rifle being fired is heard, but Silvanito is not actually pulling the trigger.        See more  \xc2\xbb\n    '],
#  ['\nCertificate:\nPG\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial site\n\n\n',
#   '\nCountry:\nJapan\n',
#   '\nLanguage:\nJapanese\n',
#   '\nRelease Date: 2 August 1986 (Japan)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Castle in the Sky\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nOpening Weekend:         $1,315,182        \n\n      (France)\n      (17 January 2003)\n',
#   '\nProduction Co:\n\nNibariki,        \nStudio Ghibli,        \nTokuma Shoten \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n125 min\n',
#   '\nSound Mix:\nDolby\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   '\nTrivia\nHayao Miyazaki: [flying] As the title suggests, the castle of Laputa flies. Numerous flying contraptions feature in the movie.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nWhen Dola announces that Goliath is off of the port bow, she looks in horror towards the Tiger Moth's starboard stern, the opposite direction from that which she announces.        See more  \xc2\xbb\n    ",
#   "\nCrazy Credits\nThe end credits show the remains of the castle Laputa floating on Earth's orbit.        See more  \xc2\xbb\n    "],
#  ['\nTaglines:\nThe Nation Awaits...                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated R for some language\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial site\n|\nOfficial site [France]\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nUK\n|\nUSA\n|\nAustralia\n',
#   '\nLanguage:\nEnglish\n',
#   '\nRelease Date: 25 December 2010 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: El discurso del rey\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nHalton House, Halton, Wendover, Buckinghamshire, England, UK\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $15,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         $355,450        \n\n      (USA)\n      (26 November 2010)\n',
#   '\nGross:        $138,795,342        \n\n      (USA)\n(10 June 2011)\n',
#   '\nProduction Co:\n\nSee-Saw Films,        \nWeinstein Company, The,        \nUK Film Council \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n118 min\n',
#   '\nSound Mix:\nDolby Digital\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 1.85 : 1\n    ',
#   '\nTrivia\nThe MPAA gave the film an R rating, due entirely to the scenes where Bertie curses as part of his speech therapy or preparation for the climactic address. Bob Weinstein and Harvey Weinstein appealed, but were denied. They later submitted a cut without some of the profanity, and got a PG-13 rating. However, the R-rated version is considered the Oscar-winning one, extending a string of R-rated Best Pictures from 2005 to 2010.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nAt home, in the company of their parents, princesses Elizabeth and Margaret were called Lilibet and Margo, respectively. These names are mentioned nowhere in the film.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\nIn the end credit roll, Philip Clements is listed twice as Assistant Sound Editor.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nAudrey Hepburn at her Oscar-winning best in an immortal comedy-romance!                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nCertificate:\nNot Rated\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n|\nItalian\n|\nGerman\n',
#   '\nRelease Date: 2 September 1953 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: La princesa que quer\xc3\xada vivir\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nViale del Policlinico, Rome, Lazio, Italy\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $1,500,000        \n\n      (estimated)\n',
#   '\nProduction Co:\n\nParamount Pictures \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n118 min\n|\n117 min\n            (cut)\n    ',
#   '\nSound Mix:\nMono\n(Western Electric Recording)    ',
#   '\nColor:\n Black and White\n(archive footage)|  Black and White\n',
#   '\nAspect Ratio: 1.37 : 1\n    ',
#   '\nTrivia\nThe journalists which were greeted by Princess Ann were actual journalists who working in the Italian offices of their newspapers and agencies.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nWhen we see, for the first time, the truck where the princess is escaping the palace, there is a Cinzano box inside, but when Anne climbs into the back of the truck, the brand "Cinzano" is not seen any more and another brand appears instead.        See more  \xc2\xbb\n    '],
#  ['\nCertificate:\nUnrated\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nCountry:\nJapan\n',
#   '\nLanguage:\nJapanese\n',
#   '\nRelease Date: 22 November 1961 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Throne of Blood\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nGotemba, Shizuoka, Japan\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nProduction Co:\n\nToho Company,        \nKurosawa Production Co. \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n110 min\n',
#   '\nSound Mix:\nMono\n(Western Electric Recording)| Mono\n(Perspecta Sound encoding)    ',
#   '\nColor:\n Black and White\n',
#   '\nAspect Ratio: 1.37 : 1\n    ',
#   "\nTrivia\nThe story is based on William Shakespeare's early-17th-century play Macbeth, which was in turn based on a medieval Scottish legend.        See more  \xc2\xbb\n    ",
#   "\nGoofs\nAfter Macbeth and Banquo come to the forest clearing where the spirit dwells, as they get down from their horses, all of Macbeth's arrows fall out of his quiver. In the next shot however, the quiver is full of arrows again.        See more  \xc2\xbb\n    "],
#  ['\nTaglines:\nThere Is Nothing Under The Sun Like The High Adventure Of "High Noon"!                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG for some western violence, and smoking\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n|\nSpanish\n',
#   '\nRelease Date: 30 July 1952 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: A la hora se\xc3\xb1alada\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nBrooks Ranch, Jamestown, California, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $750,000        \n\n      (estimated)\n',
#   '\nProduction Co:\n\nStanley Kramer Productions \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n85 min\n',
#   '\nSound Mix:\nMono\n(Western Electric Recording)    ',
#   '\nColor:\n Black and White\n',
#   '\nAspect Ratio: 1.37 : 1\n    ',
#   '\nTrivia\nAlthough the film takes place between 10:35 a.m. and 12:15 p.m, you would need to start watching the film at 10:50 a.m. in order for Noon in real life to synchronize with the "High Noon" of the film.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nThe position of Kane's hat during the scene where the judge is packing to leave.        See more  \xc2\xbb\n    "],
#  ['\nCertificate:\n\n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nOfficial Facebook\n|\nOfficial site\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nIndia\n',
#   '\nLanguage:\nHindi\n',
#   '\nRelease Date: 2 August 2012 (Singapore)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Bande Vasejpura\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nVaranasi, Uttar Pradesh, India\n',
#   '\nBudget:        INR\xc2\xa0184,000,000        \n\n      (estimated)\n',
#   '\nProduction Co:\n\nJar Pictures,        \nAKFPL,        \nBohra Bros Productions \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n320 min\n            (2 parts)\n    ',
#   '\nSound Mix:\nDolby Digital\n| Datasat\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 2.35 : 1\n    ',
#   '\nTrivia\nSardar Khan name was suggested by Manoj Bajpayee himself instead of Zeeshan Khan.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nWhile 'Faizal Khan' come out of the banaras jail when he is arrested for the first time for having pistol with him during search in train,we can clearly see mobile battery etc not allowed in the right side of the jail door.Since the scene was of early 90's the mobile phone was not used during those days.        See more  \xc2\xbb\n    ",
#   '\nCrazy Credits\nThe opening credits are in black and white and distorted, to reflect the style of the times in which the opening is set.        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nThe most beautiful love story ever told.                \n See more\xc2\xa0\xc2\xbb\n                \n',
#   '\nCertificate:\nG\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nDisney [Japan]\n|\nOfficial Facebook\n|\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nCountry:\nUSA\n',
#   '\nLanguage:\nEnglish\n|\nFrench\n',
#   '\nRelease Date: 22 November 1991 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: Beauty and the Beast 3-D\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nWalt Disney Feature Animation - 500 S. Buena Vista Street, Burbank, California, USA\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nBudget:        $25,000,000        \n\n      (estimated)\n',
#   '\nOpening Weekend:         \xc2\xa344,797        \n\n      (UK)\n      (4 January 2002)\n',
#   '\nGross:        $218,967,620        \n\n      (USA)\n(4 May 2012)\n',
#   '\nProduction Co:\n\nWalt Disney Pictures,        \nSilver Screen Partners IV,        \nWalt Disney Feature Animation \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n84 min\n|\n91 min\n            (special edition)\n    ',
#   '\nSound Mix:\nDolby Stereo\n(Surround Sound)\xc2\xa0(L-R)| 70 mm 6-Track\n(5.1 Surround Sound)\xc2\xa0(70 mm prints)| DTS\n(DTS-HD Master Audio 7.1)| Dolby Digital\n(special edition)| DTS\n(special edition)| SDDS\n(special edition)    ',
#   '\nColor:\nColor\n(Technicolor)    ',
#   '\nAspect Ratio: 1.78 : 1 / (high definition)\n    ',
#   '\nTrivia\nRob Minkoff was approached to be the director, but the studio turned him down because he wanted complete creative control.        See more  \xc2\xbb\n    ',
#   '\nGoofs\nIn the scene where the Beast is overlooking Belle from the balcony, you see in the far shot that her dress is blue. However, in the close up shot, her dress is obviously green.        See more  \xc2\xbb\n    ',
#   '\nCrazy Credits\n"To our friend, Howard, who gave a mermaid her voice and a beast his soul, we will be forever grateful. Howard Ashman (1950-1991)"        See more  \xc2\xbb\n    '],
#  ['\nTaglines:\nFeel the heat, keep the feeling burning, let the sensation explode.        ',
#   '\nMotion Picture Rating\n                    (MPAA)\n                \nRated PG for thematic elements and brief language\n| \n See all certifications\xc2\xa0\xc2\xbb\n            \n',
#   '\nParents Guide:\n\n View content advisory\xc2\xa0\xc2\xbb\n        \n',
#   '\nOfficial Sites:\nJet Tone Films Ltd [Hong Kong]\n\n\n',
#   '\nCountry:\nHong Kong\n|\nChina\n',
#   '\nLanguage:\nCantonese\n|\nShanghainese\n|\nFrench\n',
#   '\nRelease Date: 9 March 2001 (USA)\n    \nSee more\xc2\xa0\xc2\xbb\n    \n',
#   '\nAlso Known As: In the Mood for Love\n      \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nFilming Locations:\nAngkor Wat, Siem Reap, Cambodia\n\nSee more\xc2\xa0\xc2\xbb\n      \n',
#   '\nOpening Weekend:         \xc2\xa392,227        \n\n      (UK)\n      (27 October 2000)\n',
#   '\nGross:        $2,734,044        \n\n      (USA)\n(1 June 2001)\n',
#   '\nProduction Co:\n\nBlock 2 Pictures,        \nJet Tone Production,        \nParadis Films \nSee more\xc2\xa0\xc2\xbb\n      \n',
#   ' \n  Show detailed\ncompany contact information\n  on \n  IMDbPro\xc2\xa0\xc2\xbb\n  ',
#   '\nRuntime:\n98 min\n',
#   '\nSound Mix:\nDolby Digital\n',
#   '\nColor:\nColor\n',
#   '\nAspect Ratio: 1.66 : 1\n    ',
#   '\nTrivia\nKar-Wai Wong was shooting the finale, and editing the film a little over a week before its debut at Cannes.        See more  \xc2\xbb\n    ',
#   "\nGoofs\nAt around 10:00, while they are using the rice cooker that Mr. Chan brought from his trip, Mrs. Chan's newspaper is inconsistently open/closed between shots.        See more  \xc2\xbb\n    "]]

# %%
foreign_notNR = top[(top['cert'] != 'Not Rated') & (top['origin'] != 'USA')]

foreign_NR = top[(top['cert'] == 'Not Rated') & (top['origin'] != 'USA')]

domestic_notNR = top[(top['cert'] != 'Not Rated') & (top['origin'] == 'USA')]

domestic_NR = top[(top['cert'] == 'Not Rated') & (top['origin'] == 'USA')]

# %% [markdown]
# Most 'Not Rated' and 'Approved' movies in the list are pre-1970; after 1970, almost all of the 'Not Rated' movies are non-USA.

# %%
# x = float(len(foreign_notNR_post1970))/ (len(foreign_notNR_post1970) + len(foreign_NR_post1970))

# print 'Proportion of non-\'Not Rated\' foreign films to \'Not Rated\' foreign films post-1970: %s' %x
# Out:
# Proportion of non-'Not Rated' foreign films to 'Not Rated' foreign films post-1970: 0.9

# %% [markdown]
# And, as we see below, all domestic films since 1970 are non-'Not Rated':

# %%
# y = float(len(domestic_notNR_post1970))/ (len(domestic_notNR_post1970) + len(domestic_NR_post1970))

# print 'Proportion of non-\'Not Rated\' domestic films to \'Not Rated\' domestic films post-1970: %s' %y
# Out:
# Proportion of non-'Not Rated' domestic films to 'Not Rated' domestic films post-1970: 1.0

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')


# set area of dot proportional-ish to rating
area = (top_scaled['rating'] + 1.4)*30

# plot number of votes by year of release
plt.scatter(foreign_notNR['year'], foreign_notNR['num_votes']/1000000, color = 'GoldenRod', \
            marker = 'o', alpha = 0.8, \
            s = area, \
            label = 'foreign_notNR_post1970')
plt.scatter(foreign_NR['year'], foreign_NR['num_votes']/1000000, color = 'GoldenRod', \
            marker = 'x', alpha = 0.8, \
            s = area, \
            label = 'foreign_NR_post1970')
plt.scatter(domestic_notNR['year'], domestic_notNR['num_votes']/1000000, color = 'IndianRed', \
            marker = 'o', alpha = 0.8, \
            s = area, \
            label = 'domestic_notNR_post1970')
plt.scatter(domestic_NR['year'], domestic_NR['num_votes']/1000000, color = 'IndianRed', \
            marker = 'x', alpha = 0.8, \
            s = area, \
            label = 'domestic_NR_post1970')

plt.title('Number of Votes by Year of Release Post-1970 (Top 250)', fontsize = 22)

# add x-axis line and a line to show current year
plt.axhline(0, color='black', alpha = 0.6)
plt.axvline(2016, color='black', linestyle='dashed', linewidth=0.8, label = 'current year (2016)')

# y label
plt.ylabel('Number of Votes (x 1 million)')

# x label
plt.xlabel('Year of Release')

# set the figure boundaries
plt.xlim([min(top['year'])-5, 2020])
plt.ylim([0, 2.5])

plt.grid(True)
plt.legend(loc='upper right', fontsize = 12)
plt.annotate('**area of points is proportional to rating', (1,0), (-200, -20), \
             xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 12)
plt.show()

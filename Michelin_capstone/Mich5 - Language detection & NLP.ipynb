# %%
import goslate
gs = goslate.Goslate()
language_id = gs.detect('orange')
gs.get_languages()[language_id]
# Out:
# u'English'

# %%
import pandas as pd
import cPickle
world_soups = cPickle.load(open('world_soup_pre1of10_chromedriver.p', 'rb'))

# %%
len(world_soups)
# Out:
# 384

# %%
from bs4 import BeautifulSoup
import pprint
soup0 = BeautifulSoup(world_soups[380], 'html.parser')
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(soup0)
# Out:
# <!DOCTYPE html>\n<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:v="urn:schemas-microsoft-com:vml"><head><script async="" src="//www.google-analytics.com/analytics.js"></script><script async="" data-owner="proxy" src="//ssl.google-analytics.com/ga.js" type="text/javascript"></script>\n<meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n<meta charset="unicode-escape"/>\n<meta content="#1095f9" name="theme-color"/>\n<title>La Bergerie\xa0- Fraisse-Cabard\xe8s\xa0:\xa0a Michelin Guide restaurant</title>\n<meta content="La Bergerie: Michelin Guide review, users review, type of cuisine, opening times, meal prices .." name="description"/>\n<meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>\n<meta content="yes" name="apple-mobile-web-app-capable"/>\n<meta content="app-id=443142682" name="apple-itunes-app"/>\n<meta content="app-id=com.viamichelin.android.viamichelinmobile" name="google-play-app"/>\n<meta content="https://www.viamichelin.c
# ...

# %%
import pandas as pd
import pandas_datareader.data as web
import datetime
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
start = datetime.datetime(2016, 01, 01)
end = datetime.datetime(2016, 07, 31)

# %%
tesla = web.DataReader('TSLA', 'yahoo', start, end)
wf = web.DataReader('WFM', 'yahoo', start, end)
target = web.DataReader('TGT', 'yahoo', start, end)
lauder = web.DataReader('EL', 'yahoo', start, end)

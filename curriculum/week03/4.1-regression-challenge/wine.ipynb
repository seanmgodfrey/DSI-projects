# %%
import pandas as pd

# %%
df = pd.read_csv("../4.1-regression-challenge/class_wine_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           0            6.3              0.30         0.34             1.6
# 1           1            7.2              0.23         0.32             8.5
# 2           2            7.2              0.23         0.32             8.5
# 3           3            8.1              0.28         0.40             6.9
# 4           4            6.2              0.32         0.16             7.0
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.049                 14.0                 132.0   0.9940  3.30
# 1      0.058                 47.0                 186.0   0.9956  3.19
# 2      0.058                 47.0                 186.0   0.9956  3.19
# 3      0.050                 30.0                  97.0   0.9951  3.26
# 4      0.045                 30.0                 136.0   0.9949  3.18
#
#    sulphates  alcohol  quality   type
# 0       0.49      9.5        6  white
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# type                     object
# dtype: object

# %%
del df['Unnamed: 0']
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.3              0.30         0.34             1.6      0.049
# 1            7.2              0.23         0.32             8.5      0.058
# 2            7.2              0.23         0.32             8.5      0.058
# 3            8.1              0.28         0.40             6.9      0.050
# 4            6.2              0.32         0.16             7.0      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 14.0                 132.0   0.9940  3.30       0.49
# 1                 47.0                 186.0   0.9956  3.19       0.40
# 2                 47.0                 186.0   0.9956  3.19       0.40
# 3                 30.0                  97.0   0.9951  3.26       0.44
# 4                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality   type
# 0      9.5        6  white
# 1      9.9        6  white
# ...
